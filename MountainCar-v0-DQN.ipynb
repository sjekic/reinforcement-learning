# %% [markdown]
# # MountainCar-v0 DQN

# %%
import os
import gc
import torch
import pygame
import warnings
import numpy as np
import torch.nn as nn
import gymnasium as gym
import torch.optim as optim
from collections import deque
import matplotlib.pyplot as plt


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

gc.collect()
torch.cuda.empty_cache()
os.environ['CUDA_LAUNCH_BLOCKING'] = '1' # Used for debugging; CUDA related errors shown immediately.

# Seed everything for reproducible results
seed = 2024
np.random.seed(seed)
np.random.default_rng(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

ENV_NAME = 'MountainCar-v0'

class ReplayMemory:
    def __init__(self, capacity):
        """
        Experience Replay Memory defined by deques to store transitions/agent experiences
        """
        
        self.capacity = capacity
        
        self.states       = deque(maxlen=capacity)
        self.actions      = deque(maxlen=capacity)
        self.next_states  = deque(maxlen=capacity)
        self.rewards      = deque(maxlen=capacity)
        self.dones        = deque(maxlen=capacity)
        
        
    def store(self, state, action, next_state, reward, done):
        """
        Append (store) the transitions to their respective deques
        """
        
        self.states.append(state)
        self.actions.append(action)
        self.next_states.append(next_state)
        self.rewards.append(reward)
        self.dones.append(done)
        
        
    def sample(self, batch_size):
        """
        Randomly sample transitions from memory, then convert sampled transitions
        to tensors and move to device (CPU or GPU).
        """
        
        indices = np.random.choice(len(self), size=batch_size, replace=False)

        states = torch.stack([torch.as_tensor(self.states[i], dtype=torch.float32, device=device) for i in indices]).to(device)
        actions = torch.as_tensor([self.actions[i] for i in indices], dtype=torch.long, device=device)
        next_states = torch.stack([torch.as_tensor(self.next_states[i], dtype=torch.float32, device=device) for i in indices]).to(device)
        rewards = torch.as_tensor([self.rewards[i] for i in indices], dtype=torch.float32, device=device)
        dones = torch.as_tensor([self.dones[i] for i in indices], dtype=torch.bool, device=device)

        return states, actions, next_states, rewards, dones
    
    
    def __len__(self):
        """
        To check how many samples are stored in the memory. self.dones deque 
        represents the length of the entire memory.
        """
        
        return len(self.dones)
    
    
class DQN_Network(nn.Module):
    """
    The Deep Q-Network (DQN) model for reinforcement learning.
    This network consists of Fully Connected (FC) layers with ReLU activation functions.
    """
    
    def __init__(self, num_actions, input_dim):
        """
        Initialize the DQN network.
        
        Parameters:
            num_actions (int): The number of possible actions in the environment.
            input_dim (int): The dimensionality of the input state space.
        """
        
        super(DQN_Network, self).__init__()
                                                          
        self.FC = nn.Sequential(
            nn.Linear(input_dim, 12),
            nn.ReLU(inplace=True),
            nn.Linear(12, 8),
            nn.ReLU(inplace=True),
            nn.Linear(8, num_actions)
            )
        
        # Initialize FC layer weights using He initialization
        for layer in [self.FC]:
            for module in layer:
                if isinstance(module, nn.Linear):
                    nn.init.kaiming_uniform_(module.weight, nonlinearity='relu')
        
        
    def forward(self, x):
        """
        Forward pass of the network to find the Q-values of the actions.
        
        Parameters:
            x (torch.Tensor): Input tensor representing the state.
        
        Returns:
            Q (torch.Tensor): Tensor containing Q-values for each action.
        """
        
        Q = self.FC(x)    
        return Q
    
        
class DQN_Agent:
    """
    DQN Agent Class. This class defines some key elements of the DQN algorithm,
    such as the learning method, hard update, and action selection based on the
    Q-value of actions or the epsilon-greedy policy.
    """
    
    def __init__(self, env, epsilon_max, epsilon_min, epsilon_decay, 
                  clip_grad_norm, learning_rate, discount, memory_capacity):
        
        # To save the history of network loss
        self.loss_history = []
        self.running_loss = 0
        self.learned_counts = 0
                     
        # RL hyperparameters
        self.epsilon_max   = epsilon_max
        self.epsilon_min   = epsilon_min
        self.epsilon_decay = epsilon_decay
        self.discount      = discount

        self.action_space  = env.action_space
        self.action_space.seed(seed) # Set the seed to get reproducible results when sampling the action space 
        self.observation_space = env.observation_space
        self.replay_memory = ReplayMemory(memory_capacity)
        
        # Initiate the network models
        input_dim = self.observation_space.shape[0]
        output_dim = self.action_space.n
        
        self.main_network = DQN_Network(num_actions=output_dim, input_dim=input_dim).to(device)
        self.target_network = DQN_Network(num_actions=output_dim, input_dim=input_dim).to(device).eval()
        self.target_network.load_state_dict(self.main_network.state_dict())

        self.clip_grad_norm = clip_grad_norm # For clipping exploding gradients caused by high reward value
        self.critertion = nn.MSELoss()
        self.optimizer = optim.Adam(self.main_network.parameters(), lr=learning_rate)
                

    def select_action(self, state):
        """
        Selects an action using epsilon-greedy strategy OR based on the Q-values.
        
        Parameters:
            state (torch.Tensor): Input tensor representing the state.
        
        Returns:
            action (int): The selected action.
        """
        
        # Exploration: epsilon-greedy
        if np.random.random() < self.epsilon_max:
            return self.action_space.sample()
        
        # Exploitation: the action is selected based on the Q-values.   
        # Check if the state is a tensor or not. If not, make it a tensor
        if not torch.is_tensor(state):
            state = torch.as_tensor(state, dtype=torch.float32, device=device)
        
        with torch.no_grad():
            Q_values = self.main_network(state)
            action = torch.argmax(Q_values).item()
                        
            return action
   

    def learn(self, batch_size, done):
        """
        Train the main network using a batch of experiences sampled from the replay memory.
        
        Parameters:
            batch_size (int): The number of experiences to sample from the replay memory.
            done (bool): Indicates whether the episode is done or not. If done,
            calculate the loss of the episode and append it in a list for plot.
        """ 
        
        # Sample a batch of experiences from the replay memory
        states, actions, next_states, rewards, dones = self.replay_memory.sample(batch_size)
                    
        
        # # The following prints are for debugging. Use them to indicate the correct shape of the tensors.
        # print('Before--------Before')
        # print("states:", states.shape)
        # print("actions:", actions.shape)
        # print("next_states:", next_states.shape)
        # print("rewards:", rewards.shape)
        # print("dones:", dones.shape)
               
         
        # # Preprocess the data for training
        # states        = states.unsqueeze(1)
        # next_states   = next_states.unsqueeze(1)
        actions       = actions.unsqueeze(1)
        rewards       = rewards.unsqueeze(1)
        dones         = dones.unsqueeze(1)       
        
        
        # # The following prints are for debugging. Use them to indicate the correct shape of the tensors.
        # print()
        # print('After--------After')
        # print("states:", states.shape)
        # print("actions:", actions.shape)
        # print("next_states:", next_states.shape)
        # print("rewards:", rewards.shape)
        # print("dones:", dones.shape)
      
        
        predicted_q = self.main_network(states) # forward pass through the main network to find the Q-values of the states
        predicted_q = predicted_q.gather(dim=1, index=actions) # selecting the Q-values of the actions that were actually taken

        # Compute the maximum Q-value for the next states using the target network
        with torch.no_grad():            
            next_target_q_value = self.target_network(next_states).max(dim=1, keepdim=True)[0] # not argmax (cause we want the maxmimum q-value, not the action that maximize it)
            
        
        next_target_q_value[dones] = 0 # Set the Q-value for terminal states to zero
        y_js = rewards + (self.discount * next_target_q_value) # Compute the target Q-values
        loss = self.critertion(predicted_q, y_js) # Compute the loss
        
        # Update the running loss and learned counts for logging and plotting
        self.running_loss += loss.item()
        self.learned_counts += 1

        if done:
            episode_loss = self.running_loss / self.learned_counts # The average loss for the episode
            self.loss_history.append(episode_loss) # Append the episode loss to the loss history for plotting
            # Reset the running loss and learned counts
            self.running_loss = 0
            self.learned_counts = 0
            
        self.optimizer.zero_grad() # Zero the gradients
        loss.backward() # Perform backward pass and update the gradients
        
        # # Uncomment the following two lines to find the best value for clipping gradient (Comment torch.nn.utils.clip_grad_norm_ while uncommenting the following two lines)
        # grad_norm_before_clip = torch.nn.utils.clip_grad_norm_(self.main_network.parameters(), float('inf'))
        # print("Gradient norm before clipping:", grad_norm_before_clip)
        
        # Clip the gradients to prevent exploding gradients
        torch.nn.utils.clip_grad_norm_(self.main_network.parameters(), self.clip_grad_norm)
        
        self.optimizer.step() # Update the parameters of the main network using the optimizer
 

    def hard_update(self):
        """
        Navie update: Update the target network parameters by directly copying 
        the parameters from the main network.
        """
        
        self.target_network.load_state_dict(self.main_network.state_dict())

    
    def update_epsilon(self):
        """
        Update the value of epsilon for epsilon-greedy exploration.
        
        This method decreases epsilon over time according to a decay factor, ensuring
        that the agent becomes less exploratory and more exploitative as training progresses.
        """
        
        self.epsilon_max = max(self.epsilon_min, self.epsilon_max * self.epsilon_decay)
        

    def save(self, path):
        """
        Save the parameters of the main network to a file with .pth extention.
        
        """
        torch.save(self.main_network.state_dict(), path)


class step_wrapper(gym.Wrapper):
    """
    A wrapper class for modifying the state and reward functions of the 
    MountainCar-v0 environment.
    """
    
    def __init__(self, env):
        """
        Initializes the StepWrapper. This is the main class for wrapping the environment with it.

        Args:
            env (gym.Env): The environment to be wrapped.
    
        Attributes:
            observation_wrapper (Inherit from ObservationWrapper): 
                An instance of the ObservationWrapper class for modifying observations.
            reward_wrapper (Inherit from RewardWrapper): 
                An instance of the RewardWrapper class for modifying rewards.
        """
        super().__init__(env) # We give the env here to initialize the gym.Wrapper superclass (inherited).
        
        self.observation_wrapper = observation_wrapper(env)
        self.reward_wrapper = reward_wrapper(env)
        
               
    def step(self, action):
        """
        Executes a step in the environment with the provided action.The reason 
        behind using this method is to have access to the state and reward functions return.
        
        Args:
            action (int): The action to be taken.
        """

        state, reward, done, truncation, info = self.env.step(action) # Same as before as usual
        
        modified_state = self.observation_wrapper.observation(state) # Give the state to another Wrapper, which returns a modified version of state
        modified_reward = self.reward_wrapper.reward(modified_state) # Give the modified state to another Wrapper to return the modified reward
                
        return modified_state, modified_reward, done, truncation, info # The same returns as usual but with modified versions of the state and reward functions
    
    
    def reset(self, seed):
        state, info = self.env.reset(seed=seed) # Same as before as usual
        modified_state = self.observation_wrapper.observation(state) # Give the state to another Wrapper, which returns a modified version of state
        
        return modified_state, info # Same as before as usual but with returning the modified version of the state
    

class observation_wrapper(gym.ObservationWrapper):
    """
    Wrapper class for modifying observations in the MountainCar-v0 environment.

    Args:
        env (gym.Env): The environment to wrap.

    Attributes:
        min_value (numpy.ndarray): Array of minimum observation values (2 dimensions because of the state.).
        max_value (numpy.ndarray): Array of maximum observation values (2 dimensions because of the state.).
    """
    
    def __init__(self, env):
        super().__init__(env)
 
        self.min_value = env.observation_space.low
        self.max_value = env.observation_space.high
        
        
    def observation(self, state):
        """
        Modifies the observation by clipping the values and normalizing it.

        Args:
            state (numpy.ndarray): The original observation from the environment.

        Returns:
            numpy.ndarray: The modified and normalized observation.
        """
        
        normalized_state = (state - self.min_value) / (self.max_value - self.min_value) # Min-max normalization
        
        return normalized_state
    
    
class reward_wrapper(gym.RewardWrapper):
    """
    Wrapper class for modifying rewards in the MountainCar-v0 environment.
    
    Args:
        env (gym.Env): The environment to wrap.
    """
    
    def __init__(self, env):
        super().__init__(env)
    
    
    def reward(self, state):
        """
        Modifies the reward based on the current state of the environment.
        
        Args:
            state (numpy.ndarray): The current state of the environment.
        
        Returns:
            float: The modified reward.
        """

        current_position, current_velocity = state # extract the position and current velocity based on the state     
        
        # Interpolate the value to the desired range (because the velocity normalized value would be in range of 0 to 1 and now it would be in range of -0.5 to 0.5)
        current_velocity = np.interp(current_velocity, np.array([0, 1]), np.array([-0.5, 0.5]))
        
        # (1) Calculate the modified reward based on the current position and velocity of the car.
        degree = current_position * 360
        degree2radian = np.deg2rad(degree)
        modified_reward =  0.2 * (np.cos(degree2radian) + 2 * np.abs(current_velocity))
        
        # (2) Step limitation
        modified_reward -= 0.5 # Subtract 0.5 to adjust the base reward (to limit useless steps).
        
        # (3) Check if the car has surpassed a threshold of the path and is closer to the goal
        if current_position > 0.98:
            modified_reward += 20  # Add a bonus reward (Reached the goal)
        elif current_position > 0.92: 
            modified_reward += 10 # So close to the goal
        elif current_position > 0.82:
            modified_reward += 6 # car is closer to the goal
        elif current_position > 0.65:
            modified_reward += 1 - np.exp(-2 * current_position) # car is getting close. Thus, giving reward based on the position and the further it reached
            
        
        # (4) Check if the car is coming down with velocity from left and goes with full velocity to right
        initial_position = 0.40842572 # Normalized value of initial position of the car which is extracted manually
        
        if current_velocity > 0.3 and current_position > initial_position + 0.1:
            modified_reward += 1 + 2 * current_position  # Add a bonus reward for this desired behavior
        
        return modified_reward
    

class Model_TrainTest():
    def __init__(self, hyperparams):
        
        # Define RL Hyperparameters
        self.train_mode             = hyperparams["train_mode"]
        self.RL_load_path           = hyperparams["RL_load_path"]
        self.save_path              = hyperparams["save_path"]
        self.save_interval          = hyperparams["save_interval"]
        
        self.clip_grad_norm         = hyperparams["clip_grad_norm"]
        self.learning_rate          = hyperparams["learning_rate"]
        self.discount_factor        = hyperparams["discount_factor"]
        self.batch_size             = hyperparams["batch_size"]
        self.update_frequency       = hyperparams["update_frequency"]
        self.max_episodes           = hyperparams["max_episodes"]
        self.max_steps              = hyperparams["max_steps"]
        self.render                 = hyperparams["render"]
        
        self.epsilon_max            = hyperparams["epsilon_max"]
        self.epsilon_min            = hyperparams["epsilon_min"]
        self.epsilon_decay          = hyperparams["epsilon_decay"]
        
        self.memory_capacity        = hyperparams["memory_capacity"]
        
        self.render_fps             = hyperparams["render_fps"]
                        
        # Define Env
        self.env = gym.make(ENV_NAME, max_episode_steps=self.max_steps, 
                            render_mode="human" if self.render else None)
        self.env.metadata['render_fps'] = self.render_fps # For max frame rate make it 0
        
        """
        The 'MountainCar-v0' environment in the 'gymnasium' library generates 
        UserWarnings about deprecated methods.
        These warnings are related to the 'size' and 'shape' methods which are 
        being phased out in a future version of the library.
        Even though we are not directly using these methods in our code, the 
        warnings are still displayed.
        To keep our output clean and focused on our own program's execution, 
        the following line of code is for ignoring these warnings.
        """
        warnings.filterwarnings("ignore", category=UserWarning)
        
        # Apply RewardWrapper
        self.env = step_wrapper(self.env)
        
        # Define the agent class
        self.agent = DQN_Agent(env               = self.env, 
                               epsilon_max       = self.epsilon_max, 
                               epsilon_min       = self.epsilon_min, 
                               epsilon_decay     = self.epsilon_decay,
                               clip_grad_norm    = self.clip_grad_norm,
                               learning_rate     = self.learning_rate,
                               discount          = self.discount_factor,
                               memory_capacity   = self.memory_capacity)
                           
    
    def train(self): 
        """                
        Reinforcement learning training loop.
        """
        
        total_steps = 0
        self.reward_history = []
        
        # Training loop over episodes
        for episode in range(1, self.max_episodes+1):
            state, _ = self.env.reset(seed=seed)
            done = False
            truncation = False
            step_size = 0
            episode_reward = 0
                                                
            while not done and not truncation:
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                
                self.agent.replay_memory.store(state, action, next_state, reward, done) 
                
                if len(self.agent.replay_memory) > self.batch_size:
                    self.agent.learn(self.batch_size, (done or truncation))
                
                    # Update target-network weights
                    if total_steps % self.update_frequency == 0:
                        self.agent.hard_update()
                
                state = next_state
                episode_reward += reward
                step_size +=1
                            
            # Appends for tracking history
            self.reward_history.append(episode_reward) # episode reward                        
            total_steps += step_size
                                                                           
            # Decay epsilon at the end of each episode
            self.agent.update_epsilon()
                            
            #-- based on interval
            if episode % self.save_interval == 0:
                self.agent.save(self.save_path + '_' + f'{episode}' + '.pth')
                if episode != self.max_episodes:
                    self.plot_training(episode)
                print('\n~~~~~~Interval Save: Model saved.\n')
    
            result = (f"Episode: {episode}, "
                      f"Total Steps: {total_steps}, "
                      f"Ep Step: {step_size}, "
                      f"Raw Reward: {episode_reward:.2f}, "
                      f"Epsilon: {self.agent.epsilon_max:.2f}")
            print(result)
        self.plot_training(episode)
                                                                    

    def test(self, max_episodes):  
        """                
        Reinforcement learning policy evaluation.
        """
           
        # Load the weights of the test_network
        self.agent.main_network.load_state_dict(torch.load(self.RL_load_path))
        self.agent.main_network.eval()
        
        # Testing loop over episodes
        for episode in range(1, max_episodes+1):         
            state, _ = self.env.reset(seed=seed)
            done = False
            truncation = False
            step_size = 0
            episode_reward = 0
                                                           
            while not done and not truncation:
                action = self.agent.select_action(state)
                next_state, reward, done, truncation, _ = self.env.step(action)
                                
                state = next_state
                episode_reward += reward
                step_size += 1
                                                                                                                       
            # Print log            
            result = (f"Episode: {episode}, "
                      f"Steps: {step_size:}, "
                      f"Reward: {episode_reward:.2f}, ")
            print(result)
            
        pygame.quit() # close the rendering window
        
    
    def plot_training(self, episode):
        # Calculate the Simple Moving Average (SMA) with a window size of 50
        sma = np.convolve(self.reward_history, np.ones(50)/50, mode='valid')
        
        # Clip max (high) values for better plot analysis 
        reward_history = np.clip(self.reward_history, a_min=None, a_max=100)
        sma = np.clip(sma, a_min=None, a_max=100)
                
        plt.figure()
        plt.title("Obtained Rewards")
        plt.plot(reward_history, label='Raw Reward', color='#4BA754', alpha=1)
        plt.plot(sma, label='SMA 50', color='#F08100')
        plt.xlabel("Episode")
        plt.ylabel("Rewards")
        plt.legend()
        
        # Only save as file if last episode
        if episode == self.max_episodes:
            plt.savefig('./reward_plot.png', format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
        plt.clf()
        plt.close() 
        
                
        plt.figure()
        plt.title("Network Loss")
        plt.plot(self.agent.loss_history, label='Loss', color='#8921BB', alpha=1)
        plt.xlabel("Episode")
        plt.ylabel("Loss")
        
        # Only save as file if last episode
        if episode == self.max_episodes:
            plt.savefig('./Loss_plot.png', format='png', dpi=600, bbox_inches='tight')
        plt.tight_layout()
        plt.grid(True)
        plt.show()
# Out:
# pygame-ce 2.5.7 (SDL 2.32.10, Python 3.12.8)

# %%
# Parameters:
train_mode = True # False

render = not train_mode

RL_hyperparams = {
    "train_mode"            : train_mode,
    "RL_load_path"          : './final_weights' + '_' + '1000' + '.pth',
    "save_path"             : './final_weights',
    "save_interval"         : 100,
    
    "clip_grad_norm"        : 5,
    "learning_rate"         : 75e-5,
    "discount_factor"       : 0.96,
    "batch_size"            : 64,
    "update_frequency"      : 20,
    "max_episodes"          : 1000           if train_mode else 2,
    "max_steps"             : 200,
    "render"                : render,
    
    "epsilon_max"           : 0.999         if train_mode else -1,
    "epsilon_min"           : 0.01,
    "epsilon_decay"         : 0.997,
    
    "memory_capacity"       : 125_000        if train_mode else 0,
    
    "render_fps"            : 60,
    }

# %%
# Run
DRL = Model_TrainTest(RL_hyperparams) # Define the instance

# Train
if train_mode:
    DRL.train()
else:
    # Test
    DRL.test(max_episodes = RL_hyperparams['max_episodes'])
# Out:
# Episode: 1, Total Steps: 200, Ep Step: 200, Raw Reward: -121.35, Epsilon: 1.00
# Episode: 2, Total Steps: 400, Ep Step: 200, Raw Reward: -118.05, Epsilon: 0.99
# Episode: 3, Total Steps: 600, Ep Step: 200, Raw Reward: -123.61, Epsilon: 0.99
# Episode: 4, Total Steps: 800, Ep Step: 200, Raw Reward: -124.11, Epsilon: 0.99
# Episode: 5, Total Steps: 1000, Ep Step: 200, Raw Reward: -125.10, Epsilon: 0.98
# Episode: 6, Total Steps: 1200, Ep Step: 200, Raw Reward: -125.05, Epsilon: 0.98
# Episode: 7, Total Steps: 1400, Ep Step: 200, Raw Reward: -124.76, Epsilon: 0.98
# Episode: 8, Total Steps: 1600, Ep Step: 200, Raw Reward: -126.04, Epsilon: 0.98
# Episode: 9, Total Steps: 1800, Ep Step: 200, Raw Reward: -122.82, Epsilon: 0.97
# Episode: 10, Total Steps: 2000, Ep Step: 200, Raw Reward: -125.00, Epsilon: 0.97
# Episode: 11, Total Steps: 2200, Ep Step: 200, Raw Reward: -120.70, Epsilon: 0.97
# Episode: 12, Total Steps: 2400, Ep Step: 200, Raw Reward: -124.39, Epsilon: 0.96
# Episode: 13, Total Steps: 2600, Ep Step: 200, Raw Reward: -125.36, Epsilon: 0.96
# Episode: 14, Total Steps: 2800, Ep Step: 200, Raw Reward: -120.80, Epsilon: 0.96
# Episode: 15, Total Steps: 3000, Ep Step: 200, Raw Reward: -125.38, Epsilon: 0.95
# Episode: 16, Total Steps: 3200, Ep Step: 200, Raw Reward: -121.35, Epsilon: 0.95
# Episode: 17, Total Steps: 3400, Ep Step: 200, Raw Reward: -125.91, Epsilon: 0.95
# Episode: 18, Total Steps: 3600, Ep Step: 200, Raw Reward: -123.81, Epsilon: 0.95
# Episode: 19, Total Steps: 3800, Ep Step: 200, Raw Reward: -125.70, Epsilon: 0.94
# Episode: 20, Total Steps: 4000, Ep Step: 200, Raw Reward: -119.71, Epsilon: 0.94
# Episode: 21, Total Steps: 4200, Ep Step: 200, Raw Reward: -124.75, Epsilon: 0.94
# Episode: 22, Total Steps: 4400, Ep Step: 200, Raw Reward: -124.94, Epsilon: 0.94
# Episode: 23, Total Steps: 4600, Ep Step: 200, Raw Reward: -123.43, Epsilon: 0.93
# Episode: 24, Total Steps: 4800, Ep Step: 200, Raw Reward: -124.81, Epsilon: 0.93
# Episode: 25, Total Steps: 5000, Ep Step: 200, Raw Reward: -122.41, Epsilon: 0.93
# Episode: 26, Total Steps: 5200, Ep Step: 200, Raw Reward: -121.82, Epsilon: 0.92
# Episode: 27, Total Steps: 5400, Ep Step: 200, Raw Reward: -119.59, Epsilon: 0.92
# Episode: 28, Total Steps: 5600, Ep Step: 200, Raw Reward: -122.43, Epsilon: 0.92
# Episode: 29, Total Steps: 5800, Ep Step: 200, Raw Reward: -123.48, Epsilon: 0.92
# Episode: 30, Total Steps: 6000, Ep Step: 200, Raw Reward: -124.46, Epsilon: 0.91
# Episode: 31, Total Steps: 6200, Ep Step: 200, Raw Reward: -116.85, Epsilon: 0.91
# Episode: 32, Total Steps: 6400, Ep Step: 200, Raw Reward: -122.51, Epsilon: 0.91
# Episode: 33, Total Steps: 6600, Ep Step: 200, Raw Reward: -125.33, Epsilon: 0.90
# Episode: 34, Total Steps: 6800, Ep Step: 200, Raw Reward: -123.39, Epsilon: 0.90
# Episode: 35, Total Steps: 7000, Ep Step: 200, Raw Reward: -118.79, Epsilon: 0.90
# Episode: 36, Total Steps: 7200, Ep Step: 200, Raw Reward: -116.03, Epsilon: 0.90
# Episode: 37, Total Steps: 7400, Ep Step: 200, Raw Reward: -124.83, Epsilon: 0.89
# Episode: 38, Total Steps: 7600, Ep Step: 200, Raw Reward: -119.81, Epsilon: 0.89
# Episode: 39, Total Steps: 7800, Ep Step: 200, Raw Reward: -124.48, Epsilon: 0.89
# Episode: 40, Total Steps: 8000, Ep Step: 200, Raw Reward: -120.79, Epsilon: 0.89
# Episode: 41, Total Steps: 8200, Ep Step: 200, Raw Reward: -125.10, Epsilon: 0.88
# Episode: 42, Total Steps: 8400, Ep Step: 200, Raw Reward: -118.90, Epsilon: 0.88
# Episode: 43, Total Steps: 8600, Ep Step: 200, Raw Reward: -117.55, Epsilon: 0.88
# Episode: 44, Total Steps: 8800, Ep Step: 200, Raw Reward: -123.76, Epsilon: 0.88
# Episode: 45, Total Steps: 9000, Ep Step: 200, Raw Reward: -116.02, Epsilon: 0.87
# Episode: 46, Total Steps: 9200, Ep Step: 200, Raw Reward: -122.06, Epsilon: 0.87
# Episode: 47, Total Steps: 9400, Ep Step: 200, Raw Reward: -124.63, Epsilon: 0.87
# Episode: 48, Total Steps: 9600, Ep Step: 200, Raw Reward: -124.68, Epsilon: 0.86
# Episode: 49, Total Steps: 9800, Ep Step: 200, Raw Reward: -119.95, Epsilon: 0.86
# Episode: 50, Total Steps: 10000, Ep Step: 200, Raw Reward: -117.88, Epsilon: 0.86
# Episode: 51, Total Steps: 10200, Ep Step: 200, Raw Reward: -122.07, Epsilon: 0.86
# Episode: 52, Total Steps: 10400, Ep Step: 200, Raw Reward: -126.00, Epsilon: 0.85
# Episode: 53, Total Steps: 10600, Ep Step: 200, Raw Reward: -117.52, Epsilon: 0.85
# Episode: 54, Total Steps: 10800, Ep Step: 200, Raw Reward: -124.00, Epsilon: 0.85
# Episode: 55, Total Steps: 11000, Ep Step: 200, Raw Reward: -125.00, Epsilon: 0.85
# Episode: 56, Total Steps: 11200, Ep Step: 200, Raw Reward: -122.39, Epsilon: 0.84
# Episode: 57, Total Steps: 11400, Ep Step: 200, Raw Reward: -120.15, Epsilon: 0.84
# Episode: 58, Total Steps: 11600, Ep Step: 200, Raw Reward: -124.20, Epsilon: 0.84
# Episode: 59, Total Steps: 11800, Ep Step: 200, Raw Reward: -125.98, Epsilon: 0.84
# Episode: 60, Total Steps: 12000, Ep Step: 200, Raw Reward: -124.00, Epsilon: 0.83
# Episode: 61, Total Steps: 12200, Ep Step: 200, Raw Reward: -120.57, Epsilon: 0.83
# Episode: 62, Total Steps: 12400, Ep Step: 200, Raw Reward: -122.66, Epsilon: 0.83
# Episode: 63, Total Steps: 12600, Ep Step: 200, Raw Reward: -116.63, Epsilon: 0.83
# Episode: 64, Total Steps: 12800, Ep Step: 200, Raw Reward: -122.13, Epsilon: 0.82
# Episode: 65, Total Steps: 13000, Ep Step: 200, Raw Reward: -122.86, Epsilon: 0.82
# Episode: 66, Total Steps: 13200, Ep Step: 200, Raw Reward: -121.19, Epsilon: 0.82
# Episode: 67, Total Steps: 13400, Ep Step: 200, Raw Reward: -119.12, Epsilon: 0.82
# Episode: 68, Total Steps: 13600, Ep Step: 200, Raw Reward: -120.58, Epsilon: 0.81
# Episode: 69, Total Steps: 13800, Ep Step: 200, Raw Reward: -116.44, Epsilon: 0.81
# Episode: 70, Total Steps: 14000, Ep Step: 200, Raw Reward: -122.88, Epsilon: 0.81
# Episode: 71, Total Steps: 14200, Ep Step: 200, Raw Reward: -120.58, Epsilon: 0.81
# Episode: 72, Total Steps: 14400, Ep Step: 200, Raw Reward: -123.34, Epsilon: 0.80
# Episode: 73, Total Steps: 14600, Ep Step: 200, Raw Reward: -123.57, Epsilon: 0.80
# Episode: 74, Total Steps: 14800, Ep Step: 200, Raw Reward: -117.02, Epsilon: 0.80
# Episode: 75, Total Steps: 15000, Ep Step: 200, Raw Reward: -115.24, Epsilon: 0.80
# Episode: 76, Total Steps: 15200, Ep Step: 200, Raw Reward: -123.39, Epsilon: 0.80
# Episode: 77, Total Steps: 15400, Ep Step: 200, Raw Reward: -115.01, Epsilon: 0.79
# Episode: 78, Total Steps: 15600, Ep Step: 200, Raw Reward: -121.06, Epsilon: 0.79
# Episode: 79, Total Steps: 15800, Ep Step: 200, Raw Reward: -116.50, Epsilon: 0.79
# Episode: 80, Total Steps: 16000, Ep Step: 200, Raw Reward: -123.10, Epsilon: 0.79
# Episode: 81, Total Steps: 16200, Ep Step: 200, Raw Reward: -119.99, Epsilon: 0.78
# Episode: 82, Total Steps: 16400, Ep Step: 200, Raw Reward: -121.42, Epsilon: 0.78
# Episode: 83, Total Steps: 16600, Ep Step: 200, Raw Reward: -121.27, Epsilon: 0.78
# Episode: 84, Total Steps: 16800, Ep Step: 200, Raw Reward: -121.46, Epsilon: 0.78
# Episode: 85, Total Steps: 17000, Ep Step: 200, Raw Reward: -122.97, Epsilon: 0.77
# Episode: 86, Total Steps: 17200, Ep Step: 200, Raw Reward: -121.26, Epsilon: 0.77
# Episode: 87, Total Steps: 17400, Ep Step: 200, Raw Reward: -118.73, Epsilon: 0.77
# Episode: 88, Total Steps: 17600, Ep Step: 200, Raw Reward: -121.21, Epsilon: 0.77
# Episode: 89, Total Steps: 17800, Ep Step: 200, Raw Reward: -120.53, Epsilon: 0.76
# Episode: 90, Total Steps: 18000, Ep Step: 200, Raw Reward: -120.66, Epsilon: 0.76
# Episode: 91, Total Steps: 18200, Ep Step: 200, Raw Reward: -119.59, Epsilon: 0.76
# Episode: 92, Total Steps: 18400, Ep Step: 200, Raw Reward: -122.90, Epsilon: 0.76
# Episode: 93, Total Steps: 18600, Ep Step: 200, Raw Reward: -116.48, Epsilon: 0.76
# Episode: 94, Total Steps: 18800, Ep Step: 200, Raw Reward: -117.88, Epsilon: 0.75
# Episode: 95, Total Steps: 19000, Ep Step: 200, Raw Reward: -122.03, Epsilon: 0.75
# Episode: 96, Total Steps: 19200, Ep Step: 200, Raw Reward: -122.65, Epsilon: 0.75
# Episode: 97, Total Steps: 19400, Ep Step: 200, Raw Reward: -114.35, Epsilon: 0.75
# Episode: 98, Total Steps: 19600, Ep Step: 200, Raw Reward: -122.84, Epsilon: 0.74
# Episode: 99, Total Steps: 19800, Ep Step: 200, Raw Reward: -122.90, Epsilon: 0.74
# ~~~~~~Interval Save: Model saved.
#
# Episode: 100, Total Steps: 20000, Ep Step: 200, Raw Reward: -121.58, Epsilon: 0.74
# Episode: 101, Total Steps: 20200, Ep Step: 200, Raw Reward: -120.31, Epsilon: 0.74
# Episode: 102, Total Steps: 20400, Ep Step: 200, Raw Reward: -114.00, Epsilon: 0.74
# Episode: 103, Total Steps: 20600, Ep Step: 200, Raw Reward: -120.63, Epsilon: 0.73
# Episode: 104, Total Steps: 20800, Ep Step: 200, Raw Reward: -118.46, Epsilon: 0.73
# Episode: 105, Total Steps: 21000, Ep Step: 200, Raw Reward: -121.43, Epsilon: 0.73
# Episode: 106, Total Steps: 21200, Ep Step: 200, Raw Reward: -121.02, Epsilon: 0.73
# Episode: 107, Total Steps: 21400, Ep Step: 200, Raw Reward: -120.21, Epsilon: 0.72
# Episode: 108, Total Steps: 21600, Ep Step: 200, Raw Reward: -120.84, Epsilon: 0.72
# Episode: 109, Total Steps: 21800, Ep Step: 200, Raw Reward: -118.38, Epsilon: 0.72
# Episode: 110, Total Steps: 22000, Ep Step: 200, Raw Reward: -124.17, Epsilon: 0.72
# Episode: 111, Total Steps: 22200, Ep Step: 200, Raw Reward: -124.90, Epsilon: 0.72
# Episode: 112, Total Steps: 22400, Ep Step: 200, Raw Reward: -119.35, Epsilon: 0.71
# Episode: 113, Total Steps: 22600, Ep Step: 200, Raw Reward: -113.21, Epsilon: 0.71
# Episode: 114, Total Steps: 22800, Ep Step: 200, Raw Reward: -118.38, Epsilon: 0.71
# Episode: 115, Total Steps: 23000, Ep Step: 200, Raw Reward: -117.24, Epsilon: 0.71
# Episode: 116, Total Steps: 23200, Ep Step: 200, Raw Reward: -119.67, Epsilon: 0.71
# Episode: 117, Total Steps: 23400, Ep Step: 200, Raw Reward: -122.97, Epsilon: 0.70
# Episode: 118, Total Steps: 23600, Ep Step: 200, Raw Reward: -120.69, Epsilon: 0.70
# Episode: 119, Total Steps: 23800, Ep Step: 200, Raw Reward: -119.42, Epsilon: 0.70
# Episode: 120, Total Steps: 24000, Ep Step: 200, Raw Reward: -122.86, Epsilon: 0.70
# Episode: 121, Total Steps: 24200, Ep Step: 200, Raw Reward: -123.19, Epsilon: 0.69
# Episode: 122, Total Steps: 24400, Ep Step: 200, Raw Reward: -118.06, Epsilon: 0.69
# Episode: 123, Total Steps: 24600, Ep Step: 200, Raw Reward: -115.93, Epsilon: 0.69
# Episode: 124, Total Steps: 24800, Ep Step: 200, Raw Reward: -117.83, Epsilon: 0.69
# Episode: 125, Total Steps: 25000, Ep Step: 200, Raw Reward: -117.80, Epsilon: 0.69
# Episode: 126, Total Steps: 25200, Ep Step: 200, Raw Reward: -122.44, Epsilon: 0.68
# Episode: 127, Total Steps: 25400, Ep Step: 200, Raw Reward: -116.92, Epsilon: 0.68
# Episode: 128, Total Steps: 25600, Ep Step: 200, Raw Reward: -115.37, Epsilon: 0.68
# Episode: 129, Total Steps: 25800, Ep Step: 200, Raw Reward: -120.10, Epsilon: 0.68
# Episode: 130, Total Steps: 26000, Ep Step: 200, Raw Reward: -121.05, Epsilon: 0.68
# Episode: 131, Total Steps: 26200, Ep Step: 200, Raw Reward: -110.68, Epsilon: 0.67
# Episode: 132, Total Steps: 26400, Ep Step: 200, Raw Reward: -122.48, Epsilon: 0.67
# Episode: 133, Total Steps: 26600, Ep Step: 200, Raw Reward: -117.07, Epsilon: 0.67
# Episode: 134, Total Steps: 26800, Ep Step: 200, Raw Reward: -119.00, Epsilon: 0.67
# Episode: 135, Total Steps: 27000, Ep Step: 200, Raw Reward: -114.12, Epsilon: 0.67
# Episode: 136, Total Steps: 27200, Ep Step: 200, Raw Reward: -117.43, Epsilon: 0.66
# Episode: 137, Total Steps: 27400, Ep Step: 200, Raw Reward: -119.91, Epsilon: 0.66
# Episode: 138, Total Steps: 27600, Ep Step: 200, Raw Reward: -121.05, Epsilon: 0.66
# Episode: 139, Total Steps: 27800, Ep Step: 200, Raw Reward: -119.00, Epsilon: 0.66
# Episode: 140, Total Steps: 28000, Ep Step: 200, Raw Reward: -120.88, Epsilon: 0.66
# Episode: 141, Total Steps: 28200, Ep Step: 200, Raw Reward: -112.21, Epsilon: 0.65
# Episode: 142, Total Steps: 28400, Ep Step: 200, Raw Reward: -118.54, Epsilon: 0.65
# Episode: 143, Total Steps: 28600, Ep Step: 200, Raw Reward: -121.60, Epsilon: 0.65
# Episode: 144, Total Steps: 28800, Ep Step: 200, Raw Reward: -113.89, Epsilon: 0.65
# Episode: 145, Total Steps: 29000, Ep Step: 200, Raw Reward: -117.21, Epsilon: 0.65
# Episode: 146, Total Steps: 29200, Ep Step: 200, Raw Reward: -119.43, Epsilon: 0.64
# Episode: 147, Total Steps: 29400, Ep Step: 200, Raw Reward: -114.75, Epsilon: 0.64
# Episode: 148, Total Steps: 29600, Ep Step: 200, Raw Reward: -122.14, Epsilon: 0.64
# Episode: 149, Total Steps: 29800, Ep Step: 200, Raw Reward: -113.87, Epsilon: 0.64
# Episode: 150, Total Steps: 30000, Ep Step: 200, Raw Reward: -112.04, Epsilon: 0.64
# Episode: 151, Total Steps: 30200, Ep Step: 200, Raw Reward: -120.30, Epsilon: 0.63
# Episode: 152, Total Steps: 30400, Ep Step: 200, Raw Reward: -116.06, Epsilon: 0.63
# Episode: 153, Total Steps: 30600, Ep Step: 200, Raw Reward: -114.97, Epsilon: 0.63
# Episode: 154, Total Steps: 30800, Ep Step: 200, Raw Reward: -118.85, Epsilon: 0.63
# Episode: 155, Total Steps: 31000, Ep Step: 200, Raw Reward: -114.01, Epsilon: 0.63
# Episode: 156, Total Steps: 31200, Ep Step: 200, Raw Reward: -113.11, Epsilon: 0.63
# Episode: 157, Total Steps: 31400, Ep Step: 200, Raw Reward: -120.20, Epsilon: 0.62
# Episode: 158, Total Steps: 31600, Ep Step: 200, Raw Reward: -117.28, Epsilon: 0.62
# Episode: 159, Total Steps: 31800, Ep Step: 200, Raw Reward: -118.05, Epsilon: 0.62
# Episode: 160, Total Steps: 32000, Ep Step: 200, Raw Reward: -108.94, Epsilon: 0.62
# Episode: 161, Total Steps: 32200, Ep Step: 200, Raw Reward: -113.50, Epsilon: 0.62
# Episode: 162, Total Steps: 32400, Ep Step: 200, Raw Reward: -114.68, Epsilon: 0.61
# Episode: 163, Total Steps: 32600, Ep Step: 200, Raw Reward: -119.70, Epsilon: 0.61
# Episode: 164, Total Steps: 32800, Ep Step: 200, Raw Reward: -116.26, Epsilon: 0.61
# Episode: 165, Total Steps: 33000, Ep Step: 200, Raw Reward: -115.08, Epsilon: 0.61
# Episode: 166, Total Steps: 33200, Ep Step: 200, Raw Reward: -118.95, Epsilon: 0.61
# Episode: 167, Total Steps: 33400, Ep Step: 200, Raw Reward: -114.13, Epsilon: 0.60
# Episode: 168, Total Steps: 33600, Ep Step: 200, Raw Reward: -120.86, Epsilon: 0.60
# Episode: 169, Total Steps: 33800, Ep Step: 200, Raw Reward: -118.67, Epsilon: 0.60
# Episode: 170, Total Steps: 34000, Ep Step: 200, Raw Reward: -120.17, Epsilon: 0.60
# Episode: 171, Total Steps: 34200, Ep Step: 200, Raw Reward: -107.76, Epsilon: 0.60
# Episode: 172, Total Steps: 34400, Ep Step: 200, Raw Reward: -114.72, Epsilon: 0.60
# Episode: 173, Total Steps: 34600, Ep Step: 200, Raw Reward: -118.35, Epsilon: 0.59
# Episode: 174, Total Steps: 34800, Ep Step: 200, Raw Reward: -115.04, Epsilon: 0.59
# Episode: 175, Total Steps: 35000, Ep Step: 200, Raw Reward: -116.12, Epsilon: 0.59
# Episode: 176, Total Steps: 35200, Ep Step: 200, Raw Reward: -117.85, Epsilon: 0.59
# Episode: 177, Total Steps: 35400, Ep Step: 200, Raw Reward: -117.02, Epsilon: 0.59
# Episode: 178, Total Steps: 35600, Ep Step: 200, Raw Reward: -118.07, Epsilon: 0.59
# Episode: 179, Total Steps: 35800, Ep Step: 200, Raw Reward: -114.05, Epsilon: 0.58
# Episode: 180, Total Steps: 36000, Ep Step: 200, Raw Reward: -108.82, Epsilon: 0.58
# Episode: 181, Total Steps: 36200, Ep Step: 200, Raw Reward: -116.48, Epsilon: 0.58
# Episode: 182, Total Steps: 36400, Ep Step: 200, Raw Reward: -115.63, Epsilon: 0.58
# Episode: 183, Total Steps: 36600, Ep Step: 200, Raw Reward: -121.54, Epsilon: 0.58
# Episode: 184, Total Steps: 36800, Ep Step: 200, Raw Reward: -110.87, Epsilon: 0.57
# Episode: 185, Total Steps: 37000, Ep Step: 200, Raw Reward: -112.23, Epsilon: 0.57
# Episode: 186, Total Steps: 37200, Ep Step: 200, Raw Reward: -119.71, Epsilon: 0.57
# Episode: 187, Total Steps: 37400, Ep Step: 200, Raw Reward: -118.03, Epsilon: 0.57
# Episode: 188, Total Steps: 37600, Ep Step: 200, Raw Reward: -114.55, Epsilon: 0.57
# Episode: 189, Total Steps: 37800, Ep Step: 200, Raw Reward: -113.51, Epsilon: 0.57
# Episode: 190, Total Steps: 38000, Ep Step: 200, Raw Reward: -113.78, Epsilon: 0.56
# Episode: 191, Total Steps: 38200, Ep Step: 200, Raw Reward: -112.87, Epsilon: 0.56
# Episode: 192, Total Steps: 38400, Ep Step: 200, Raw Reward: -118.64, Epsilon: 0.56
# Episode: 193, Total Steps: 38600, Ep Step: 200, Raw Reward: -112.98, Epsilon: 0.56
# Episode: 194, Total Steps: 38800, Ep Step: 200, Raw Reward: -113.10, Epsilon: 0.56
# Episode: 195, Total Steps: 39000, Ep Step: 200, Raw Reward: -119.19, Epsilon: 0.56
# Episode: 196, Total Steps: 39200, Ep Step: 200, Raw Reward: -112.46, Epsilon: 0.55
# Episode: 197, Total Steps: 39400, Ep Step: 200, Raw Reward: -117.12, Epsilon: 0.55
# Episode: 198, Total Steps: 39600, Ep Step: 200, Raw Reward: -108.91, Epsilon: 0.55
# Episode: 199, Total Steps: 39800, Ep Step: 200, Raw Reward: -114.83, Epsilon: 0.55
# ~~~~~~Interval Save: Model saved.
#
# Episode: 200, Total Steps: 40000, Ep Step: 200, Raw Reward: -107.57, Epsilon: 0.55
# Episode: 201, Total Steps: 40200, Ep Step: 200, Raw Reward: -112.23, Epsilon: 0.55
# Episode: 202, Total Steps: 40400, Ep Step: 200, Raw Reward: -118.79, Epsilon: 0.54
# Episode: 203, Total Steps: 40600, Ep Step: 200, Raw Reward: -115.14, Epsilon: 0.54
# Episode: 204, Total Steps: 40800, Ep Step: 200, Raw Reward: -108.87, Epsilon: 0.54
# Episode: 205, Total Steps: 41000, Ep Step: 200, Raw Reward: -116.69, Epsilon: 0.54
# Episode: 206, Total Steps: 41200, Ep Step: 200, Raw Reward: -117.55, Epsilon: 0.54
# Episode: 207, Total Steps: 41400, Ep Step: 200, Raw Reward: -110.64, Epsilon: 0.54
# Episode: 208, Total Steps: 41600, Ep Step: 200, Raw Reward: -117.81, Epsilon: 0.53
# Episode: 209, Total Steps: 41800, Ep Step: 200, Raw Reward: -112.74, Epsilon: 0.53
# Episode: 210, Total Steps: 42000, Ep Step: 200, Raw Reward: -118.85, Epsilon: 0.53
# Episode: 211, Total Steps: 42200, Ep Step: 200, Raw Reward: -107.42, Epsilon: 0.53
# Episode: 212, Total Steps: 42400, Ep Step: 200, Raw Reward: -115.27, Epsilon: 0.53
# Episode: 213, Total Steps: 42600, Ep Step: 200, Raw Reward: -112.49, Epsilon: 0.53
# Episode: 214, Total Steps: 42800, Ep Step: 200, Raw Reward: -113.41, Epsilon: 0.53
# Episode: 215, Total Steps: 43000, Ep Step: 200, Raw Reward: -115.54, Epsilon: 0.52
# Episode: 216, Total Steps: 43200, Ep Step: 200, Raw Reward: -118.36, Epsilon: 0.52
# Episode: 217, Total Steps: 43400, Ep Step: 200, Raw Reward: -111.97, Epsilon: 0.52
# Episode: 218, Total Steps: 43600, Ep Step: 200, Raw Reward: -114.85, Epsilon: 0.52
# Episode: 219, Total Steps: 43800, Ep Step: 200, Raw Reward: -114.87, Epsilon: 0.52
# Episode: 220, Total Steps: 44000, Ep Step: 200, Raw Reward: -111.63, Epsilon: 0.52
# Episode: 221, Total Steps: 44200, Ep Step: 200, Raw Reward: -111.13, Epsilon: 0.51
# Episode: 222, Total Steps: 44400, Ep Step: 200, Raw Reward: -111.98, Epsilon: 0.51
# Episode: 223, Total Steps: 44600, Ep Step: 200, Raw Reward: -118.39, Epsilon: 0.51
# Episode: 224, Total Steps: 44800, Ep Step: 200, Raw Reward: -109.21, Epsilon: 0.51
# Episode: 225, Total Steps: 45000, Ep Step: 200, Raw Reward: -115.98, Epsilon: 0.51
# Episode: 226, Total Steps: 45200, Ep Step: 200, Raw Reward: -113.85, Epsilon: 0.51
# Episode: 227, Total Steps: 45400, Ep Step: 200, Raw Reward: -116.76, Epsilon: 0.51
# Episode: 228, Total Steps: 45600, Ep Step: 200, Raw Reward: -111.02, Epsilon: 0.50
# Episode: 229, Total Steps: 45800, Ep Step: 200, Raw Reward: -108.84, Epsilon: 0.50
# Episode: 230, Total Steps: 46000, Ep Step: 200, Raw Reward: -113.83, Epsilon: 0.50
# Episode: 231, Total Steps: 46200, Ep Step: 200, Raw Reward: -107.21, Epsilon: 0.50
# Episode: 232, Total Steps: 46400, Ep Step: 200, Raw Reward: -111.34, Epsilon: 0.50
# Episode: 233, Total Steps: 46600, Ep Step: 200, Raw Reward: -103.05, Epsilon: 0.50
# Episode: 234, Total Steps: 46800, Ep Step: 200, Raw Reward: -118.03, Epsilon: 0.49
# Episode: 235, Total Steps: 47000, Ep Step: 200, Raw Reward: -112.98, Epsilon: 0.49
# Episode: 236, Total Steps: 47200, Ep Step: 200, Raw Reward: -109.91, Epsilon: 0.49
# Episode: 237, Total Steps: 47400, Ep Step: 200, Raw Reward: -111.35, Epsilon: 0.49
# Episode: 238, Total Steps: 47600, Ep Step: 200, Raw Reward: -110.85, Epsilon: 0.49
# Episode: 239, Total Steps: 47800, Ep Step: 200, Raw Reward: -110.71, Epsilon: 0.49
# Episode: 240, Total Steps: 48000, Ep Step: 200, Raw Reward: -91.48, Epsilon: 0.49
# Episode: 241, Total Steps: 48200, Ep Step: 200, Raw Reward: -117.97, Epsilon: 0.48
# Episode: 242, Total Steps: 48400, Ep Step: 200, Raw Reward: -112.29, Epsilon: 0.48
# Episode: 243, Total Steps: 48600, Ep Step: 200, Raw Reward: -105.29, Epsilon: 0.48
# Episode: 244, Total Steps: 48800, Ep Step: 200, Raw Reward: -112.17, Epsilon: 0.48
# Episode: 245, Total Steps: 49000, Ep Step: 200, Raw Reward: -113.49, Epsilon: 0.48
# Episode: 246, Total Steps: 49200, Ep Step: 200, Raw Reward: -117.06, Epsilon: 0.48
# Episode: 247, Total Steps: 49400, Ep Step: 200, Raw Reward: -110.27, Epsilon: 0.48
# Episode: 248, Total Steps: 49600, Ep Step: 200, Raw Reward: -106.34, Epsilon: 0.47
# Episode: 249, Total Steps: 49800, Ep Step: 200, Raw Reward: -102.24, Epsilon: 0.47
# Episode: 250, Total Steps: 50000, Ep Step: 200, Raw Reward: -112.43, Epsilon: 0.47
# Episode: 251, Total Steps: 50200, Ep Step: 200, Raw Reward: -108.44, Epsilon: 0.47
# Episode: 252, Total Steps: 50400, Ep Step: 200, Raw Reward: -115.06, Epsilon: 0.47
# Episode: 253, Total Steps: 50600, Ep Step: 200, Raw Reward: -115.91, Epsilon: 0.47
# Episode: 254, Total Steps: 50800, Ep Step: 200, Raw Reward: -110.02, Epsilon: 0.47
# Episode: 255, Total Steps: 51000, Ep Step: 200, Raw Reward: -112.50, Epsilon: 0.46
# Episode: 256, Total Steps: 51200, Ep Step: 200, Raw Reward: -114.38, Epsilon: 0.46
# Episode: 257, Total Steps: 51400, Ep Step: 200, Raw Reward: -108.87, Epsilon: 0.46
# Episode: 258, Total Steps: 51600, Ep Step: 200, Raw Reward: 52.03, Epsilon: 0.46
# Episode: 259, Total Steps: 51800, Ep Step: 200, Raw Reward: -108.64, Epsilon: 0.46
# Episode: 260, Total Steps: 52000, Ep Step: 200, Raw Reward: -118.77, Epsilon: 0.46
# Episode: 261, Total Steps: 52200, Ep Step: 200, Raw Reward: -114.95, Epsilon: 0.46
# Episode: 262, Total Steps: 52400, Ep Step: 200, Raw Reward: -114.44, Epsilon: 0.45
# Episode: 263, Total Steps: 52600, Ep Step: 200, Raw Reward: -90.00, Epsilon: 0.45
# Episode: 264, Total Steps: 52800, Ep Step: 200, Raw Reward: -116.82, Epsilon: 0.45
# Episode: 265, Total Steps: 53000, Ep Step: 200, Raw Reward: -107.88, Epsilon: 0.45
# Episode: 266, Total Steps: 53200, Ep Step: 200, Raw Reward: -112.49, Epsilon: 0.45
# Episode: 267, Total Steps: 53400, Ep Step: 200, Raw Reward: -93.16, Epsilon: 0.45
# Episode: 268, Total Steps: 53600, Ep Step: 200, Raw Reward: -83.06, Epsilon: 0.45
# Episode: 269, Total Steps: 53800, Ep Step: 200, Raw Reward: -75.37, Epsilon: 0.45
# Episode: 270, Total Steps: 54000, Ep Step: 200, Raw Reward: -113.43, Epsilon: 0.44
# Episode: 271, Total Steps: 54200, Ep Step: 200, Raw Reward: -112.05, Epsilon: 0.44
# Episode: 272, Total Steps: 54381, Ep Step: 181, Raw Reward: 17.24, Epsilon: 0.44
# Episode: 273, Total Steps: 54573, Ep Step: 192, Raw Reward: 61.23, Epsilon: 0.44
# Episode: 274, Total Steps: 54773, Ep Step: 200, Raw Reward: -85.40, Epsilon: 0.44
# Episode: 275, Total Steps: 54973, Ep Step: 200, Raw Reward: -77.94, Epsilon: 0.44
# Episode: 276, Total Steps: 55137, Ep Step: 164, Raw Reward: 4.32, Epsilon: 0.44
# Episode: 277, Total Steps: 55326, Ep Step: 189, Raw Reward: 78.57, Epsilon: 0.43
# Episode: 278, Total Steps: 55497, Ep Step: 171, Raw Reward: 9.01, Epsilon: 0.43
# Episode: 279, Total Steps: 55669, Ep Step: 172, Raw Reward: 2.16, Epsilon: 0.43
# Episode: 280, Total Steps: 55869, Ep Step: 200, Raw Reward: -74.01, Epsilon: 0.43
# Episode: 281, Total Steps: 56042, Ep Step: 173, Raw Reward: 47.50, Epsilon: 0.43
# Episode: 282, Total Steps: 56209, Ep Step: 167, Raw Reward: 13.52, Epsilon: 0.43
# Episode: 283, Total Steps: 56409, Ep Step: 200, Raw Reward: -80.17, Epsilon: 0.43
# Episode: 284, Total Steps: 56587, Ep Step: 178, Raw Reward: 23.62, Epsilon: 0.43
# Episode: 285, Total Steps: 56759, Ep Step: 172, Raw Reward: -5.21, Epsilon: 0.42
# Episode: 286, Total Steps: 56925, Ep Step: 166, Raw Reward: 1.70, Epsilon: 0.42
# Episode: 287, Total Steps: 57096, Ep Step: 171, Raw Reward: 1.54, Epsilon: 0.42
# Episode: 288, Total Steps: 57296, Ep Step: 200, Raw Reward: -81.99, Epsilon: 0.42
# Episode: 289, Total Steps: 57496, Ep Step: 200, Raw Reward: -82.09, Epsilon: 0.42
# Episode: 290, Total Steps: 57696, Ep Step: 200, Raw Reward: -117.44, Epsilon: 0.42
# Episode: 291, Total Steps: 57896, Ep Step: 200, Raw Reward: -68.17, Epsilon: 0.42
# Episode: 292, Total Steps: 58096, Ep Step: 200, Raw Reward: -110.64, Epsilon: 0.42
# Episode: 293, Total Steps: 58270, Ep Step: 174, Raw Reward: -9.39, Epsilon: 0.41
# Episode: 294, Total Steps: 58440, Ep Step: 170, Raw Reward: 11.97, Epsilon: 0.41
# Episode: 295, Total Steps: 58640, Ep Step: 200, Raw Reward: -55.71, Epsilon: 0.41
# Episode: 296, Total Steps: 58840, Ep Step: 200, Raw Reward: -128.36, Epsilon: 0.41
# Episode: 297, Total Steps: 59040, Ep Step: 200, Raw Reward: -134.22, Epsilon: 0.41
# Episode: 298, Total Steps: 59240, Ep Step: 200, Raw Reward: -124.36, Epsilon: 0.41
# Episode: 299, Total Steps: 59440, Ep Step: 200, Raw Reward: -129.71, Epsilon: 0.41
# ~~~~~~Interval Save: Model saved.
#
# Episode: 300, Total Steps: 59640, Ep Step: 200, Raw Reward: -115.65, Epsilon: 0.41
# Episode: 301, Total Steps: 59840, Ep Step: 200, Raw Reward: -132.80, Epsilon: 0.40
# Episode: 302, Total Steps: 60040, Ep Step: 200, Raw Reward: -125.12, Epsilon: 0.40
# Episode: 303, Total Steps: 60240, Ep Step: 200, Raw Reward: -126.98, Epsilon: 0.40
# Episode: 304, Total Steps: 60440, Ep Step: 200, Raw Reward: -114.44, Epsilon: 0.40
# Episode: 305, Total Steps: 60640, Ep Step: 200, Raw Reward: -123.27, Epsilon: 0.40
# Episode: 306, Total Steps: 60840, Ep Step: 200, Raw Reward: -117.13, Epsilon: 0.40
# Episode: 307, Total Steps: 61040, Ep Step: 200, Raw Reward: -77.59, Epsilon: 0.40
# Episode: 308, Total Steps: 61240, Ep Step: 200, Raw Reward: -118.71, Epsilon: 0.40
# Episode: 309, Total Steps: 61440, Ep Step: 200, Raw Reward: -116.77, Epsilon: 0.39
# Episode: 310, Total Steps: 61640, Ep Step: 200, Raw Reward: 49.06, Epsilon: 0.39
# Episode: 311, Total Steps: 61840, Ep Step: 200, Raw Reward: 26.00, Epsilon: 0.39
# Episode: 312, Total Steps: 62040, Ep Step: 200, Raw Reward: -118.87, Epsilon: 0.39
# Episode: 313, Total Steps: 62240, Ep Step: 200, Raw Reward: -122.19, Epsilon: 0.39
# Episode: 314, Total Steps: 62440, Ep Step: 200, Raw Reward: -113.65, Epsilon: 0.39
# Episode: 315, Total Steps: 62640, Ep Step: 200, Raw Reward: -122.56, Epsilon: 0.39
# Episode: 316, Total Steps: 62803, Ep Step: 163, Raw Reward: -4.80, Epsilon: 0.39
# Episode: 317, Total Steps: 62998, Ep Step: 195, Raw Reward: -5.46, Epsilon: 0.39
# Episode: 318, Total Steps: 63167, Ep Step: 169, Raw Reward: -3.60, Epsilon: 0.38
# Episode: 319, Total Steps: 63343, Ep Step: 176, Raw Reward: -3.35, Epsilon: 0.38
# Episode: 320, Total Steps: 63517, Ep Step: 174, Raw Reward: -1.46, Epsilon: 0.38
# Episode: 321, Total Steps: 63690, Ep Step: 173, Raw Reward: 6.00, Epsilon: 0.38
# Episode: 322, Total Steps: 63873, Ep Step: 183, Raw Reward: -0.28, Epsilon: 0.38
# Episode: 323, Total Steps: 64043, Ep Step: 170, Raw Reward: 5.83, Epsilon: 0.38
# Episode: 324, Total Steps: 64212, Ep Step: 169, Raw Reward: 11.01, Epsilon: 0.38
# Episode: 325, Total Steps: 64412, Ep Step: 200, Raw Reward: -107.30, Epsilon: 0.38
# Episode: 326, Total Steps: 64585, Ep Step: 173, Raw Reward: 16.47, Epsilon: 0.38
# Episode: 327, Total Steps: 64754, Ep Step: 169, Raw Reward: -4.70, Epsilon: 0.37
# Episode: 328, Total Steps: 64931, Ep Step: 177, Raw Reward: -5.85, Epsilon: 0.37
# Episode: 329, Total Steps: 65101, Ep Step: 170, Raw Reward: -1.59, Epsilon: 0.37
# Episode: 330, Total Steps: 65272, Ep Step: 171, Raw Reward: -2.45, Epsilon: 0.37
# Episode: 331, Total Steps: 65454, Ep Step: 182, Raw Reward: -0.23, Epsilon: 0.37
# Episode: 332, Total Steps: 65653, Ep Step: 199, Raw Reward: -24.58, Epsilon: 0.37
# Episode: 333, Total Steps: 65842, Ep Step: 189, Raw Reward: 47.82, Epsilon: 0.37
# Episode: 334, Total Steps: 66042, Ep Step: 200, Raw Reward: -44.64, Epsilon: 0.37
# Episode: 335, Total Steps: 66222, Ep Step: 180, Raw Reward: -0.86, Epsilon: 0.37
# Episode: 336, Total Steps: 66422, Ep Step: 200, Raw Reward: -75.25, Epsilon: 0.36
# Episode: 337, Total Steps: 66619, Ep Step: 197, Raw Reward: 0.86, Epsilon: 0.36
# Episode: 338, Total Steps: 66803, Ep Step: 184, Raw Reward: -8.11, Epsilon: 0.36
# Episode: 339, Total Steps: 66971, Ep Step: 168, Raw Reward: 0.46, Epsilon: 0.36
# Episode: 340, Total Steps: 67139, Ep Step: 168, Raw Reward: 32.68, Epsilon: 0.36
# Episode: 341, Total Steps: 67309, Ep Step: 170, Raw Reward: -0.43, Epsilon: 0.36
# Episode: 342, Total Steps: 67488, Ep Step: 179, Raw Reward: -3.10, Epsilon: 0.36
# Episode: 343, Total Steps: 67658, Ep Step: 170, Raw Reward: 2.68, Epsilon: 0.36
# Episode: 344, Total Steps: 67824, Ep Step: 166, Raw Reward: -2.78, Epsilon: 0.36
# Episode: 345, Total Steps: 68022, Ep Step: 198, Raw Reward: -11.79, Epsilon: 0.35
# Episode: 346, Total Steps: 68194, Ep Step: 172, Raw Reward: -5.27, Epsilon: 0.35
# Episode: 347, Total Steps: 68389, Ep Step: 195, Raw Reward: -4.82, Epsilon: 0.35
# Episode: 348, Total Steps: 68561, Ep Step: 172, Raw Reward: 3.36, Epsilon: 0.35
# Episode: 349, Total Steps: 68725, Ep Step: 164, Raw Reward: 22.74, Epsilon: 0.35
# Episode: 350, Total Steps: 68901, Ep Step: 176, Raw Reward: 0.26, Epsilon: 0.35
# Episode: 351, Total Steps: 69101, Ep Step: 200, Raw Reward: -60.67, Epsilon: 0.35
# Episode: 352, Total Steps: 69269, Ep Step: 168, Raw Reward: -0.91, Epsilon: 0.35
# Episode: 353, Total Steps: 69425, Ep Step: 156, Raw Reward: 16.85, Epsilon: 0.35
# Episode: 354, Total Steps: 69594, Ep Step: 169, Raw Reward: -2.23, Epsilon: 0.34
# Episode: 355, Total Steps: 69747, Ep Step: 153, Raw Reward: 19.23, Epsilon: 0.34
# Episode: 356, Total Steps: 69907, Ep Step: 160, Raw Reward: 14.62, Epsilon: 0.34
# Episode: 357, Total Steps: 70107, Ep Step: 200, Raw Reward: -51.78, Epsilon: 0.34
# Episode: 358, Total Steps: 70286, Ep Step: 179, Raw Reward: -6.82, Epsilon: 0.34
# Episode: 359, Total Steps: 70443, Ep Step: 157, Raw Reward: 9.39, Epsilon: 0.34
# Episode: 360, Total Steps: 70608, Ep Step: 165, Raw Reward: 9.14, Epsilon: 0.34
# Episode: 361, Total Steps: 70808, Ep Step: 200, Raw Reward: -60.27, Epsilon: 0.34
# Episode: 362, Total Steps: 70981, Ep Step: 173, Raw Reward: -0.46, Epsilon: 0.34
# Episode: 363, Total Steps: 71181, Ep Step: 200, Raw Reward: 140.86, Epsilon: 0.34
# Episode: 364, Total Steps: 71381, Ep Step: 200, Raw Reward: -55.67, Epsilon: 0.33
# Episode: 365, Total Steps: 71560, Ep Step: 179, Raw Reward: -2.37, Epsilon: 0.33
# Episode: 366, Total Steps: 71729, Ep Step: 169, Raw Reward: 0.54, Epsilon: 0.33
# Episode: 367, Total Steps: 71929, Ep Step: 200, Raw Reward: -74.22, Epsilon: 0.33
# Episode: 368, Total Steps: 72065, Ep Step: 136, Raw Reward: 31.29, Epsilon: 0.33
# Episode: 369, Total Steps: 72238, Ep Step: 173, Raw Reward: -12.00, Epsilon: 0.33
# Episode: 370, Total Steps: 72438, Ep Step: 200, Raw Reward: -70.96, Epsilon: 0.33
# Episode: 371, Total Steps: 72638, Ep Step: 200, Raw Reward: -113.49, Epsilon: 0.33
# Episode: 372, Total Steps: 72838, Ep Step: 200, Raw Reward: -38.58, Epsilon: 0.33
# Episode: 373, Total Steps: 73038, Ep Step: 200, Raw Reward: -84.10, Epsilon: 0.33
# Episode: 374, Total Steps: 73238, Ep Step: 200, Raw Reward: -55.38, Epsilon: 0.32
# Episode: 375, Total Steps: 73406, Ep Step: 168, Raw Reward: -2.49, Epsilon: 0.32
# Episode: 376, Total Steps: 73606, Ep Step: 200, Raw Reward: -112.72, Epsilon: 0.32
# Episode: 377, Total Steps: 73806, Ep Step: 200, Raw Reward: -135.41, Epsilon: 0.32
# Episode: 378, Total Steps: 74006, Ep Step: 200, Raw Reward: -70.76, Epsilon: 0.32
# Episode: 379, Total Steps: 74206, Ep Step: 200, Raw Reward: 4.20, Epsilon: 0.32
# Episode: 380, Total Steps: 74406, Ep Step: 200, Raw Reward: -130.14, Epsilon: 0.32
# Episode: 381, Total Steps: 74606, Ep Step: 200, Raw Reward: -50.26, Epsilon: 0.32
# Episode: 382, Total Steps: 74806, Ep Step: 200, Raw Reward: -126.44, Epsilon: 0.32
# Episode: 383, Total Steps: 75003, Ep Step: 197, Raw Reward: 6.13, Epsilon: 0.32
# Episode: 384, Total Steps: 75203, Ep Step: 200, Raw Reward: -86.79, Epsilon: 0.32
# Episode: 385, Total Steps: 75403, Ep Step: 200, Raw Reward: -93.81, Epsilon: 0.31
# Episode: 386, Total Steps: 75603, Ep Step: 200, Raw Reward: -111.54, Epsilon: 0.31
# Episode: 387, Total Steps: 75803, Ep Step: 200, Raw Reward: -60.34, Epsilon: 0.31
# Episode: 388, Total Steps: 76003, Ep Step: 200, Raw Reward: -78.24, Epsilon: 0.31
# Episode: 389, Total Steps: 76203, Ep Step: 200, Raw Reward: -80.55, Epsilon: 0.31
# Episode: 390, Total Steps: 76403, Ep Step: 200, Raw Reward: -74.55, Epsilon: 0.31
# Episode: 391, Total Steps: 76603, Ep Step: 200, Raw Reward: -88.89, Epsilon: 0.31
# Episode: 392, Total Steps: 76803, Ep Step: 200, Raw Reward: -43.85, Epsilon: 0.31
# Episode: 393, Total Steps: 77003, Ep Step: 200, Raw Reward: -112.50, Epsilon: 0.31
# Episode: 394, Total Steps: 77203, Ep Step: 200, Raw Reward: -89.12, Epsilon: 0.31
# Episode: 395, Total Steps: 77403, Ep Step: 200, Raw Reward: -118.34, Epsilon: 0.30
# Episode: 396, Total Steps: 77603, Ep Step: 200, Raw Reward: -25.76, Epsilon: 0.30
# Episode: 397, Total Steps: 77803, Ep Step: 200, Raw Reward: -24.25, Epsilon: 0.30
# Episode: 398, Total Steps: 77933, Ep Step: 130, Raw Reward: 68.43, Epsilon: 0.30
# Episode: 399, Total Steps: 78133, Ep Step: 200, Raw Reward: -126.37, Epsilon: 0.30
# ~~~~~~Interval Save: Model saved.
#
# Episode: 400, Total Steps: 78333, Ep Step: 200, Raw Reward: -27.27, Epsilon: 0.30
# Episode: 401, Total Steps: 78533, Ep Step: 200, Raw Reward: -84.82, Epsilon: 0.30
# Episode: 402, Total Steps: 78733, Ep Step: 200, Raw Reward: -72.18, Epsilon: 0.30
# Episode: 403, Total Steps: 78933, Ep Step: 200, Raw Reward: -93.44, Epsilon: 0.30
# Episode: 404, Total Steps: 79133, Ep Step: 200, Raw Reward: -30.82, Epsilon: 0.30
# Episode: 405, Total Steps: 79333, Ep Step: 200, Raw Reward: -67.15, Epsilon: 0.30
# Episode: 406, Total Steps: 79533, Ep Step: 200, Raw Reward: -39.13, Epsilon: 0.29
# Episode: 407, Total Steps: 79733, Ep Step: 200, Raw Reward: -115.09, Epsilon: 0.29
# Episode: 408, Total Steps: 79933, Ep Step: 200, Raw Reward: -72.78, Epsilon: 0.29
# Episode: 409, Total Steps: 80133, Ep Step: 200, Raw Reward: -84.69, Epsilon: 0.29
# Episode: 410, Total Steps: 80333, Ep Step: 200, Raw Reward: -87.78, Epsilon: 0.29
# Episode: 411, Total Steps: 80533, Ep Step: 200, Raw Reward: -80.70, Epsilon: 0.29
# Episode: 412, Total Steps: 80733, Ep Step: 200, Raw Reward: -87.14, Epsilon: 0.29
# Episode: 413, Total Steps: 80933, Ep Step: 200, Raw Reward: -92.29, Epsilon: 0.29
# Episode: 414, Total Steps: 81133, Ep Step: 200, Raw Reward: -11.67, Epsilon: 0.29
# Episode: 415, Total Steps: 81333, Ep Step: 200, Raw Reward: -51.44, Epsilon: 0.29
# Episode: 416, Total Steps: 81533, Ep Step: 200, Raw Reward: -88.53, Epsilon: 0.29
# Episode: 417, Total Steps: 81704, Ep Step: 171, Raw Reward: 6.74, Epsilon: 0.29
# Episode: 418, Total Steps: 81902, Ep Step: 198, Raw Reward: 5.53, Epsilon: 0.28
# Episode: 419, Total Steps: 82102, Ep Step: 200, Raw Reward: -99.95, Epsilon: 0.28
# Episode: 420, Total Steps: 82302, Ep Step: 200, Raw Reward: -69.38, Epsilon: 0.28
# Episode: 421, Total Steps: 82502, Ep Step: 200, Raw Reward: -69.40, Epsilon: 0.28
# Episode: 422, Total Steps: 82702, Ep Step: 200, Raw Reward: -88.08, Epsilon: 0.28
# Episode: 423, Total Steps: 82902, Ep Step: 200, Raw Reward: -60.19, Epsilon: 0.28
# Episode: 424, Total Steps: 83102, Ep Step: 200, Raw Reward: -27.84, Epsilon: 0.28
# Episode: 425, Total Steps: 83302, Ep Step: 200, Raw Reward: 40.31, Epsilon: 0.28
# Episode: 426, Total Steps: 83502, Ep Step: 200, Raw Reward: -110.57, Epsilon: 0.28
# Episode: 427, Total Steps: 83640, Ep Step: 138, Raw Reward: 80.02, Epsilon: 0.28
# Episode: 428, Total Steps: 83840, Ep Step: 200, Raw Reward: 261.95, Epsilon: 0.28
# Episode: 429, Total Steps: 84040, Ep Step: 200, Raw Reward: -72.84, Epsilon: 0.28
# Episode: 430, Total Steps: 84203, Ep Step: 163, Raw Reward: 14.56, Epsilon: 0.27
# Episode: 431, Total Steps: 84365, Ep Step: 162, Raw Reward: 9.72, Epsilon: 0.27
# Episode: 432, Total Steps: 84524, Ep Step: 159, Raw Reward: 3.97, Epsilon: 0.27
# Episode: 433, Total Steps: 84689, Ep Step: 165, Raw Reward: 30.07, Epsilon: 0.27
# Episode: 434, Total Steps: 84846, Ep Step: 157, Raw Reward: 1.06, Epsilon: 0.27
# Episode: 435, Total Steps: 85009, Ep Step: 163, Raw Reward: -7.28, Epsilon: 0.27
# Episode: 436, Total Steps: 85172, Ep Step: 163, Raw Reward: 5.82, Epsilon: 0.27
# Episode: 437, Total Steps: 85324, Ep Step: 152, Raw Reward: 6.41, Epsilon: 0.27
# Episode: 438, Total Steps: 85524, Ep Step: 200, Raw Reward: -36.44, Epsilon: 0.27
# Episode: 439, Total Steps: 85724, Ep Step: 200, Raw Reward: -57.18, Epsilon: 0.27
# Episode: 440, Total Steps: 85883, Ep Step: 159, Raw Reward: 3.06, Epsilon: 0.27
# Episode: 441, Total Steps: 86048, Ep Step: 165, Raw Reward: 18.66, Epsilon: 0.27
# Episode: 442, Total Steps: 86214, Ep Step: 166, Raw Reward: 14.58, Epsilon: 0.26
# Episode: 443, Total Steps: 86406, Ep Step: 192, Raw Reward: 12.67, Epsilon: 0.26
# Episode: 444, Total Steps: 86606, Ep Step: 200, Raw Reward: -32.48, Epsilon: 0.26
# Episode: 445, Total Steps: 86765, Ep Step: 159, Raw Reward: -3.82, Epsilon: 0.26
# Episode: 446, Total Steps: 86929, Ep Step: 164, Raw Reward: 11.03, Epsilon: 0.26
# Episode: 447, Total Steps: 87085, Ep Step: 156, Raw Reward: 10.65, Epsilon: 0.26
# Episode: 448, Total Steps: 87210, Ep Step: 125, Raw Reward: 29.57, Epsilon: 0.26
# Episode: 449, Total Steps: 87378, Ep Step: 168, Raw Reward: -1.93, Epsilon: 0.26
# Episode: 450, Total Steps: 87578, Ep Step: 200, Raw Reward: -47.75, Epsilon: 0.26
# Episode: 451, Total Steps: 87768, Ep Step: 190, Raw Reward: 15.22, Epsilon: 0.26
# Episode: 452, Total Steps: 87922, Ep Step: 154, Raw Reward: 76.74, Epsilon: 0.26
# Episode: 453, Total Steps: 88122, Ep Step: 200, Raw Reward: 61.86, Epsilon: 0.26
# Episode: 454, Total Steps: 88313, Ep Step: 191, Raw Reward: -3.45, Epsilon: 0.26
# Episode: 455, Total Steps: 88471, Ep Step: 158, Raw Reward: 12.95, Epsilon: 0.25
# Episode: 456, Total Steps: 88671, Ep Step: 200, Raw Reward: -46.00, Epsilon: 0.25
# Episode: 457, Total Steps: 88871, Ep Step: 200, Raw Reward: 110.11, Epsilon: 0.25
# Episode: 458, Total Steps: 89034, Ep Step: 163, Raw Reward: 20.33, Epsilon: 0.25
# Episode: 459, Total Steps: 89191, Ep Step: 157, Raw Reward: 11.25, Epsilon: 0.25
# Episode: 460, Total Steps: 89349, Ep Step: 158, Raw Reward: 6.07, Epsilon: 0.25
# Episode: 461, Total Steps: 89516, Ep Step: 167, Raw Reward: 10.69, Epsilon: 0.25
# Episode: 462, Total Steps: 89716, Ep Step: 200, Raw Reward: -62.83, Epsilon: 0.25
# Episode: 463, Total Steps: 89855, Ep Step: 139, Raw Reward: 50.98, Epsilon: 0.25
# Episode: 464, Total Steps: 90055, Ep Step: 200, Raw Reward: 264.21, Epsilon: 0.25
# Episode: 465, Total Steps: 90237, Ep Step: 182, Raw Reward: 5.70, Epsilon: 0.25
# Episode: 466, Total Steps: 90431, Ep Step: 194, Raw Reward: 12.02, Epsilon: 0.25
# Episode: 467, Total Steps: 90591, Ep Step: 160, Raw Reward: 29.49, Epsilon: 0.25
# Episode: 468, Total Steps: 90754, Ep Step: 163, Raw Reward: 13.42, Epsilon: 0.24
# Episode: 469, Total Steps: 90917, Ep Step: 163, Raw Reward: 27.83, Epsilon: 0.24
# Episode: 470, Total Steps: 91117, Ep Step: 200, Raw Reward: -74.71, Epsilon: 0.24
# Episode: 471, Total Steps: 91317, Ep Step: 200, Raw Reward: -36.23, Epsilon: 0.24
# Episode: 472, Total Steps: 91515, Ep Step: 198, Raw Reward: 16.96, Epsilon: 0.24
# Episode: 473, Total Steps: 91715, Ep Step: 200, Raw Reward: -6.17, Epsilon: 0.24
# Episode: 474, Total Steps: 91915, Ep Step: 200, Raw Reward: -43.28, Epsilon: 0.24
# Episode: 475, Total Steps: 92115, Ep Step: 200, Raw Reward: 12.90, Epsilon: 0.24
# Episode: 476, Total Steps: 92315, Ep Step: 200, Raw Reward: -91.00, Epsilon: 0.24
# Episode: 477, Total Steps: 92515, Ep Step: 200, Raw Reward: 11.72, Epsilon: 0.24
# Episode: 478, Total Steps: 92633, Ep Step: 118, Raw Reward: 25.15, Epsilon: 0.24
# Episode: 479, Total Steps: 92833, Ep Step: 200, Raw Reward: 3.99, Epsilon: 0.24
# Episode: 480, Total Steps: 93033, Ep Step: 200, Raw Reward: -62.23, Epsilon: 0.24
# Episode: 481, Total Steps: 93192, Ep Step: 159, Raw Reward: 26.87, Epsilon: 0.24
# Episode: 482, Total Steps: 93392, Ep Step: 200, Raw Reward: -63.82, Epsilon: 0.23
# Episode: 483, Total Steps: 93585, Ep Step: 193, Raw Reward: -1.86, Epsilon: 0.23
# Episode: 484, Total Steps: 93735, Ep Step: 150, Raw Reward: 136.71, Epsilon: 0.23
# Episode: 485, Total Steps: 93859, Ep Step: 124, Raw Reward: 33.24, Epsilon: 0.23
# Episode: 486, Total Steps: 94054, Ep Step: 195, Raw Reward: 5.67, Epsilon: 0.23
# Episode: 487, Total Steps: 94254, Ep Step: 200, Raw Reward: 274.12, Epsilon: 0.23
# Episode: 488, Total Steps: 94434, Ep Step: 180, Raw Reward: 6.15, Epsilon: 0.23
# Episode: 489, Total Steps: 94634, Ep Step: 200, Raw Reward: 22.09, Epsilon: 0.23
# Episode: 490, Total Steps: 94834, Ep Step: 200, Raw Reward: -54.03, Epsilon: 0.23
# Episode: 491, Total Steps: 95034, Ep Step: 200, Raw Reward: 44.49, Epsilon: 0.23
# Episode: 492, Total Steps: 95234, Ep Step: 200, Raw Reward: -37.43, Epsilon: 0.23
# Episode: 493, Total Steps: 95357, Ep Step: 123, Raw Reward: 15.90, Epsilon: 0.23
# Episode: 494, Total Steps: 95557, Ep Step: 200, Raw Reward: -77.49, Epsilon: 0.23
# Episode: 495, Total Steps: 95717, Ep Step: 160, Raw Reward: 23.93, Epsilon: 0.23
# Episode: 496, Total Steps: 95878, Ep Step: 161, Raw Reward: 22.57, Epsilon: 0.23
# Episode: 497, Total Steps: 96030, Ep Step: 152, Raw Reward: 87.85, Epsilon: 0.22
# Episode: 498, Total Steps: 96187, Ep Step: 157, Raw Reward: 22.02, Epsilon: 0.22
# Episode: 499, Total Steps: 96341, Ep Step: 154, Raw Reward: 173.35, Epsilon: 0.22
# ~~~~~~Interval Save: Model saved.
#
# Episode: 500, Total Steps: 96474, Ep Step: 133, Raw Reward: 28.73, Epsilon: 0.22
# Episode: 501, Total Steps: 96674, Ep Step: 200, Raw Reward: -68.25, Epsilon: 0.22
# Episode: 502, Total Steps: 96874, Ep Step: 200, Raw Reward: -60.39, Epsilon: 0.22
# Episode: 503, Total Steps: 97074, Ep Step: 200, Raw Reward: -19.23, Epsilon: 0.22
# Episode: 504, Total Steps: 97199, Ep Step: 125, Raw Reward: 50.18, Epsilon: 0.22
# Episode: 505, Total Steps: 97370, Ep Step: 171, Raw Reward: 49.79, Epsilon: 0.22
# Episode: 506, Total Steps: 97514, Ep Step: 144, Raw Reward: 58.43, Epsilon: 0.22
# Episode: 507, Total Steps: 97648, Ep Step: 134, Raw Reward: 70.24, Epsilon: 0.22
# Episode: 508, Total Steps: 97790, Ep Step: 142, Raw Reward: 45.91, Epsilon: 0.22
# Episode: 509, Total Steps: 97925, Ep Step: 135, Raw Reward: 51.19, Epsilon: 0.22
# Episode: 510, Total Steps: 98125, Ep Step: 200, Raw Reward: -27.01, Epsilon: 0.22
# Episode: 511, Total Steps: 98245, Ep Step: 120, Raw Reward: 28.63, Epsilon: 0.22
# Episode: 512, Total Steps: 98399, Ep Step: 154, Raw Reward: 17.55, Epsilon: 0.21
# Episode: 513, Total Steps: 98523, Ep Step: 124, Raw Reward: 39.27, Epsilon: 0.21
# Episode: 514, Total Steps: 98703, Ep Step: 180, Raw Reward: 7.21, Epsilon: 0.21
# Episode: 515, Total Steps: 98825, Ep Step: 122, Raw Reward: 40.36, Epsilon: 0.21
# Episode: 516, Total Steps: 98988, Ep Step: 163, Raw Reward: 38.06, Epsilon: 0.21
# Episode: 517, Total Steps: 99155, Ep Step: 167, Raw Reward: 30.70, Epsilon: 0.21
# Episode: 518, Total Steps: 99296, Ep Step: 141, Raw Reward: 42.09, Epsilon: 0.21
# Episode: 519, Total Steps: 99496, Ep Step: 200, Raw Reward: 16.43, Epsilon: 0.21
# Episode: 520, Total Steps: 99667, Ep Step: 171, Raw Reward: 24.53, Epsilon: 0.21
# Episode: 521, Total Steps: 99867, Ep Step: 200, Raw Reward: 42.65, Epsilon: 0.21
# Episode: 522, Total Steps: 100067, Ep Step: 200, Raw Reward: -33.87, Epsilon: 0.21
# Episode: 523, Total Steps: 100188, Ep Step: 121, Raw Reward: 27.55, Epsilon: 0.21
# Episode: 524, Total Steps: 100376, Ep Step: 188, Raw Reward: 28.67, Epsilon: 0.21
# Episode: 525, Total Steps: 100503, Ep Step: 127, Raw Reward: 34.88, Epsilon: 0.21
# Episode: 526, Total Steps: 100633, Ep Step: 130, Raw Reward: 84.94, Epsilon: 0.21
# Episode: 527, Total Steps: 100771, Ep Step: 138, Raw Reward: 36.98, Epsilon: 0.21
# Episode: 528, Total Steps: 100971, Ep Step: 200, Raw Reward: -62.40, Epsilon: 0.20
# Episode: 529, Total Steps: 101133, Ep Step: 162, Raw Reward: 15.31, Epsilon: 0.20
# Episode: 530, Total Steps: 101296, Ep Step: 163, Raw Reward: 47.30, Epsilon: 0.20
# Episode: 531, Total Steps: 101464, Ep Step: 168, Raw Reward: 42.99, Epsilon: 0.20
# Episode: 532, Total Steps: 101664, Ep Step: 200, Raw Reward: -77.45, Epsilon: 0.20
# Episode: 533, Total Steps: 101805, Ep Step: 141, Raw Reward: 14.89, Epsilon: 0.20
# Episode: 534, Total Steps: 101964, Ep Step: 159, Raw Reward: 78.99, Epsilon: 0.20
# Episode: 535, Total Steps: 102127, Ep Step: 163, Raw Reward: 36.10, Epsilon: 0.20
# Episode: 536, Total Steps: 102264, Ep Step: 137, Raw Reward: 91.26, Epsilon: 0.20
# Episode: 537, Total Steps: 102464, Ep Step: 200, Raw Reward: 307.98, Epsilon: 0.20
# Episode: 538, Total Steps: 102622, Ep Step: 158, Raw Reward: 14.94, Epsilon: 0.20
# Episode: 539, Total Steps: 102822, Ep Step: 200, Raw Reward: -90.31, Epsilon: 0.20
# Episode: 540, Total Steps: 103021, Ep Step: 199, Raw Reward: 4.30, Epsilon: 0.20
# Episode: 541, Total Steps: 103179, Ep Step: 158, Raw Reward: 213.73, Epsilon: 0.20
# Episode: 542, Total Steps: 103337, Ep Step: 158, Raw Reward: 32.52, Epsilon: 0.20
# Episode: 543, Total Steps: 103537, Ep Step: 200, Raw Reward: 6.96, Epsilon: 0.20
# Episode: 544, Total Steps: 103689, Ep Step: 152, Raw Reward: 30.75, Epsilon: 0.19
# Episode: 545, Total Steps: 103878, Ep Step: 189, Raw Reward: 22.75, Epsilon: 0.19
# Episode: 546, Total Steps: 104036, Ep Step: 158, Raw Reward: 2.83, Epsilon: 0.19
# Episode: 547, Total Steps: 104165, Ep Step: 129, Raw Reward: 59.52, Epsilon: 0.19
# Episode: 548, Total Steps: 104319, Ep Step: 154, Raw Reward: 6.19, Epsilon: 0.19
# Episode: 549, Total Steps: 104486, Ep Step: 167, Raw Reward: 35.14, Epsilon: 0.19
# Episode: 550, Total Steps: 104643, Ep Step: 157, Raw Reward: 36.36, Epsilon: 0.19
# Episode: 551, Total Steps: 104771, Ep Step: 128, Raw Reward: 13.46, Epsilon: 0.19
# Episode: 552, Total Steps: 104938, Ep Step: 167, Raw Reward: 20.59, Epsilon: 0.19
# Episode: 553, Total Steps: 105138, Ep Step: 200, Raw Reward: -57.58, Epsilon: 0.19
# Episode: 554, Total Steps: 105261, Ep Step: 123, Raw Reward: 33.29, Epsilon: 0.19
# Episode: 555, Total Steps: 105461, Ep Step: 200, Raw Reward: 89.05, Epsilon: 0.19
# Episode: 556, Total Steps: 105661, Ep Step: 200, Raw Reward: -39.36, Epsilon: 0.19
# Episode: 557, Total Steps: 105790, Ep Step: 129, Raw Reward: 48.17, Epsilon: 0.19
# Episode: 558, Total Steps: 105990, Ep Step: 200, Raw Reward: -29.64, Epsilon: 0.19
# Episode: 559, Total Steps: 106115, Ep Step: 125, Raw Reward: 49.39, Epsilon: 0.19
# Episode: 560, Total Steps: 106315, Ep Step: 200, Raw Reward: -62.20, Epsilon: 0.19
# Episode: 561, Total Steps: 106470, Ep Step: 155, Raw Reward: 18.62, Epsilon: 0.19
# Episode: 562, Total Steps: 106630, Ep Step: 160, Raw Reward: 37.14, Epsilon: 0.18
# Episode: 563, Total Steps: 106768, Ep Step: 138, Raw Reward: 39.35, Epsilon: 0.18
# Episode: 564, Total Steps: 106898, Ep Step: 130, Raw Reward: 32.91, Epsilon: 0.18
# Episode: 565, Total Steps: 107051, Ep Step: 153, Raw Reward: 103.28, Epsilon: 0.18
# Episode: 566, Total Steps: 107231, Ep Step: 180, Raw Reward: 270.59, Epsilon: 0.18
# Episode: 567, Total Steps: 107367, Ep Step: 136, Raw Reward: 71.04, Epsilon: 0.18
# Episode: 568, Total Steps: 107526, Ep Step: 159, Raw Reward: 44.37, Epsilon: 0.18
# Episode: 569, Total Steps: 107726, Ep Step: 200, Raw Reward: 36.57, Epsilon: 0.18
# Episode: 570, Total Steps: 107888, Ep Step: 162, Raw Reward: 22.52, Epsilon: 0.18
# Episode: 571, Total Steps: 108015, Ep Step: 127, Raw Reward: 56.36, Epsilon: 0.18
# Episode: 572, Total Steps: 108215, Ep Step: 200, Raw Reward: 102.44, Epsilon: 0.18
# Episode: 573, Total Steps: 108340, Ep Step: 125, Raw Reward: 77.25, Epsilon: 0.18
# Episode: 574, Total Steps: 108498, Ep Step: 158, Raw Reward: 33.29, Epsilon: 0.18
# Episode: 575, Total Steps: 108652, Ep Step: 154, Raw Reward: 24.90, Epsilon: 0.18
# Episode: 576, Total Steps: 108813, Ep Step: 161, Raw Reward: 33.75, Epsilon: 0.18
# Episode: 577, Total Steps: 108975, Ep Step: 162, Raw Reward: 31.93, Epsilon: 0.18
# Episode: 578, Total Steps: 109138, Ep Step: 163, Raw Reward: 23.58, Epsilon: 0.18
# Episode: 579, Total Steps: 109289, Ep Step: 151, Raw Reward: 21.72, Epsilon: 0.18
# Episode: 580, Total Steps: 109451, Ep Step: 162, Raw Reward: 33.15, Epsilon: 0.17
# Episode: 581, Total Steps: 109616, Ep Step: 165, Raw Reward: 23.43, Epsilon: 0.17
# Episode: 582, Total Steps: 109775, Ep Step: 159, Raw Reward: 30.60, Epsilon: 0.17
# Episode: 583, Total Steps: 109932, Ep Step: 157, Raw Reward: 17.35, Epsilon: 0.17
# ...
# Episode: 808, Total Steps: 146227, Ep Step: 167, Raw Reward: 32.31, Epsilon: 0.09
# Episode: 809, Total Steps: 146398, Ep Step: 171, Raw Reward: 41.59, Epsilon: 0.09
# Episode: 810, Total Steps: 146575, Ep Step: 177, Raw Reward: 29.58, Epsilon: 0.09
# Episode: 811, Total Steps: 146748, Ep Step: 173, Raw Reward: 17.49, Epsilon: 0.09
# Episode: 812, Total Steps: 146868, Ep Step: 120, Raw Reward: 210.28, Epsilon: 0.09
# Episode: 813, Total Steps: 147051, Ep Step: 183, Raw Reward: 82.52, Epsilon: 0.09
# Episode: 814, Total Steps: 147251, Ep Step: 200, Raw Reward: 242.81, Epsilon: 0.09
# Episode: 815, Total Steps: 147440, Ep Step: 189, Raw Reward: 185.41, Epsilon: 0.09
# Episode: 816, Total Steps: 147601, Ep Step: 161, Raw Reward: 33.01, Epsilon: 0.09
# Episode: 817, Total Steps: 147762, Ep Step: 161, Raw Reward: 27.24, Epsilon: 0.09
# Episode: 818, Total Steps: 147939, Ep Step: 177, Raw Reward: 41.16, Epsilon: 0.09
# Episode: 819, Total Steps: 148125, Ep Step: 186, Raw Reward: 143.82, Epsilon: 0.09
# Episode: 820, Total Steps: 148290, Ep Step: 165, Raw Reward: 31.04, Epsilon: 0.09
# Episode: 821, Total Steps: 148479, Ep Step: 189, Raw Reward: 158.94, Epsilon: 0.08
# Episode: 822, Total Steps: 148653, Ep Step: 174, Raw Reward: 45.15, Epsilon: 0.08
# Episode: 823, Total Steps: 148817, Ep Step: 164, Raw Reward: 42.59, Epsilon: 0.08
# Episode: 824, Total Steps: 149005, Ep Step: 188, Raw Reward: 222.35, Epsilon: 0.08
# Episode: 825, Total Steps: 149171, Ep Step: 166, Raw Reward: 40.28, Epsilon: 0.08
# Episode: 826, Total Steps: 149345, Ep Step: 174, Raw Reward: 43.48, Epsilon: 0.08
# Episode: 827, Total Steps: 149541, Ep Step: 196, Raw Reward: 285.82, Epsilon: 0.08
# Episode: 828, Total Steps: 149726, Ep Step: 185, Raw Reward: 222.09, Epsilon: 0.08
# Episode: 829, Total Steps: 149900, Ep Step: 174, Raw Reward: 49.49, Epsilon: 0.08
# Episode: 830, Total Steps: 150055, Ep Step: 155, Raw Reward: 33.24, Epsilon: 0.08
# Episode: 831, Total Steps: 150165, Ep Step: 110, Raw Reward: 155.96, Epsilon: 0.08
# Episode: 832, Total Steps: 150340, Ep Step: 175, Raw Reward: 82.73, Epsilon: 0.08
# Episode: 833, Total Steps: 150509, Ep Step: 169, Raw Reward: 40.44, Epsilon: 0.08
# Episode: 834, Total Steps: 150693, Ep Step: 184, Raw Reward: 151.19, Epsilon: 0.08
# Episode: 835, Total Steps: 150885, Ep Step: 192, Raw Reward: 186.25, Epsilon: 0.08
# Episode: 836, Total Steps: 150992, Ep Step: 107, Raw Reward: 138.99, Epsilon: 0.08
# Episode: 837, Total Steps: 151184, Ep Step: 192, Raw Reward: 177.93, Epsilon: 0.08
# Episode: 838, Total Steps: 151363, Ep Step: 179, Raw Reward: 50.28, Epsilon: 0.08
# Episode: 839, Total Steps: 151471, Ep Step: 108, Raw Reward: 154.19, Epsilon: 0.08
# Episode: 840, Total Steps: 151637, Ep Step: 166, Raw Reward: 35.08, Epsilon: 0.08
# Episode: 841, Total Steps: 151760, Ep Step: 123, Raw Reward: 222.67, Epsilon: 0.08
# Episode: 842, Total Steps: 151957, Ep Step: 197, Raw Reward: 233.79, Epsilon: 0.08
# Episode: 843, Total Steps: 152133, Ep Step: 176, Raw Reward: 46.18, Epsilon: 0.08
# Episode: 844, Total Steps: 152242, Ep Step: 109, Raw Reward: 141.64, Epsilon: 0.08
# Episode: 845, Total Steps: 152435, Ep Step: 193, Raw Reward: 147.51, Epsilon: 0.08
# Episode: 846, Total Steps: 152598, Ep Step: 163, Raw Reward: 37.08, Epsilon: 0.08
# Episode: 847, Total Steps: 152705, Ep Step: 107, Raw Reward: 145.02, Epsilon: 0.08
# Episode: 848, Total Steps: 152867, Ep Step: 162, Raw Reward: 31.90, Epsilon: 0.08
# Episode: 849, Total Steps: 153038, Ep Step: 171, Raw Reward: 35.77, Epsilon: 0.08
# Episode: 850, Total Steps: 153208, Ep Step: 170, Raw Reward: 34.90, Epsilon: 0.08
# Episode: 851, Total Steps: 153385, Ep Step: 177, Raw Reward: 43.53, Epsilon: 0.08
# Episode: 852, Total Steps: 153585, Ep Step: 200, Raw Reward: 225.54, Epsilon: 0.08
# Episode: 853, Total Steps: 153748, Ep Step: 163, Raw Reward: 36.72, Epsilon: 0.08
# Episode: 854, Total Steps: 153917, Ep Step: 169, Raw Reward: 48.97, Epsilon: 0.08
# Episode: 855, Total Steps: 154090, Ep Step: 173, Raw Reward: 31.76, Epsilon: 0.08
# Episode: 856, Total Steps: 154255, Ep Step: 165, Raw Reward: 33.52, Epsilon: 0.08
# Episode: 857, Total Steps: 154421, Ep Step: 166, Raw Reward: 44.34, Epsilon: 0.08
# Episode: 858, Total Steps: 154587, Ep Step: 166, Raw Reward: 28.34, Epsilon: 0.08
# Episode: 859, Total Steps: 154754, Ep Step: 167, Raw Reward: 41.84, Epsilon: 0.08
# Episode: 860, Total Steps: 154926, Ep Step: 172, Raw Reward: 42.05, Epsilon: 0.08
# Episode: 861, Total Steps: 155084, Ep Step: 158, Raw Reward: 24.35, Epsilon: 0.08
# Episode: 862, Total Steps: 155213, Ep Step: 129, Raw Reward: 263.26, Epsilon: 0.07
# Episode: 863, Total Steps: 155381, Ep Step: 168, Raw Reward: 44.65, Epsilon: 0.07
# Episode: 864, Total Steps: 155498, Ep Step: 117, Raw Reward: 194.16, Epsilon: 0.07
# Episode: 865, Total Steps: 155665, Ep Step: 167, Raw Reward: 44.06, Epsilon: 0.07
# Episode: 866, Total Steps: 155830, Ep Step: 165, Raw Reward: 41.17, Epsilon: 0.07
# Episode: 867, Total Steps: 156001, Ep Step: 171, Raw Reward: 45.15, Epsilon: 0.07
# Episode: 868, Total Steps: 156160, Ep Step: 159, Raw Reward: 42.40, Epsilon: 0.07
# Episode: 869, Total Steps: 156319, Ep Step: 159, Raw Reward: 39.98, Epsilon: 0.07
# Episode: 870, Total Steps: 156512, Ep Step: 193, Raw Reward: 229.24, Epsilon: 0.07
# Episode: 871, Total Steps: 156712, Ep Step: 200, Raw Reward: 286.03, Epsilon: 0.07
# Episode: 872, Total Steps: 156830, Ep Step: 118, Raw Reward: 183.59, Epsilon: 0.07
# Episode: 873, Total Steps: 156999, Ep Step: 169, Raw Reward: 38.49, Epsilon: 0.07
# Episode: 874, Total Steps: 157165, Ep Step: 166, Raw Reward: 39.30, Epsilon: 0.07
# Episode: 875, Total Steps: 157345, Ep Step: 180, Raw Reward: 153.51, Epsilon: 0.07
# Episode: 876, Total Steps: 157507, Ep Step: 162, Raw Reward: 43.81, Epsilon: 0.07
# Episode: 877, Total Steps: 157612, Ep Step: 105, Raw Reward: 127.19, Epsilon: 0.07
# Episode: 878, Total Steps: 157771, Ep Step: 159, Raw Reward: 37.64, Epsilon: 0.07
# Episode: 879, Total Steps: 157929, Ep Step: 158, Raw Reward: 35.89, Epsilon: 0.07
# Episode: 880, Total Steps: 158069, Ep Step: 140, Raw Reward: 317.77, Epsilon: 0.07
# Episode: 881, Total Steps: 158253, Ep Step: 184, Raw Reward: 168.68, Epsilon: 0.07
# Episode: 882, Total Steps: 158422, Ep Step: 169, Raw Reward: 42.46, Epsilon: 0.07
# Episode: 883, Total Steps: 158578, Ep Step: 156, Raw Reward: 38.06, Epsilon: 0.07
# Episode: 884, Total Steps: 158747, Ep Step: 169, Raw Reward: 46.38, Epsilon: 0.07
# Episode: 885, Total Steps: 158898, Ep Step: 151, Raw Reward: 20.85, Epsilon: 0.07
# Episode: 886, Total Steps: 158996, Ep Step: 98, Raw Reward: 88.85, Epsilon: 0.07
# Episode: 887, Total Steps: 159183, Ep Step: 187, Raw Reward: 192.51, Epsilon: 0.07
# Episode: 888, Total Steps: 159351, Ep Step: 168, Raw Reward: 47.13, Epsilon: 0.07
# Episode: 889, Total Steps: 159514, Ep Step: 163, Raw Reward: 42.50, Epsilon: 0.07
# Episode: 890, Total Steps: 159618, Ep Step: 104, Raw Reward: 122.24, Epsilon: 0.07
# Episode: 891, Total Steps: 159729, Ep Step: 111, Raw Reward: 153.87, Epsilon: 0.07
# Episode: 892, Total Steps: 159894, Ep Step: 165, Raw Reward: 44.44, Epsilon: 0.07
# Episode: 893, Total Steps: 159993, Ep Step: 99, Raw Reward: 93.13, Epsilon: 0.07
# Episode: 894, Total Steps: 160152, Ep Step: 159, Raw Reward: 42.64, Epsilon: 0.07
# Episode: 895, Total Steps: 160330, Ep Step: 178, Raw Reward: 161.94, Epsilon: 0.07
# Episode: 896, Total Steps: 160515, Ep Step: 185, Raw Reward: 195.23, Epsilon: 0.07
# Episode: 897, Total Steps: 160648, Ep Step: 133, Raw Reward: 282.53, Epsilon: 0.07
# Episode: 898, Total Steps: 160807, Ep Step: 159, Raw Reward: 29.51, Epsilon: 0.07
# Episode: 899, Total Steps: 160963, Ep Step: 156, Raw Reward: 41.02, Epsilon: 0.07
# ~~~~~~Interval Save: Model saved.
#
# Episode: 900, Total Steps: 161141, Ep Step: 178, Raw Reward: 120.16, Epsilon: 0.07
# Episode: 901, Total Steps: 161309, Ep Step: 168, Raw Reward: 37.26, Epsilon: 0.07
# Episode: 902, Total Steps: 161472, Ep Step: 163, Raw Reward: 41.50, Epsilon: 0.07
# Episode: 903, Total Steps: 161644, Ep Step: 172, Raw Reward: 47.29, Epsilon: 0.07
# Episode: 904, Total Steps: 161809, Ep Step: 165, Raw Reward: 40.84, Epsilon: 0.07
# Episode: 905, Total Steps: 161965, Ep Step: 156, Raw Reward: 37.57, Epsilon: 0.07
# Episode: 906, Total Steps: 162124, Ep Step: 159, Raw Reward: 37.24, Epsilon: 0.07
# Episode: 907, Total Steps: 162275, Ep Step: 151, Raw Reward: 30.07, Epsilon: 0.07
# Episode: 908, Total Steps: 162446, Ep Step: 171, Raw Reward: 74.41, Epsilon: 0.07
# Episode: 909, Total Steps: 162596, Ep Step: 150, Raw Reward: 31.13, Epsilon: 0.07
# Episode: 910, Total Steps: 162742, Ep Step: 146, Raw Reward: 22.16, Epsilon: 0.06
# Episode: 911, Total Steps: 162894, Ep Step: 152, Raw Reward: 18.68, Epsilon: 0.06
# Episode: 912, Total Steps: 163040, Ep Step: 146, Raw Reward: 20.38, Epsilon: 0.06
# Episode: 913, Total Steps: 163190, Ep Step: 150, Raw Reward: 17.02, Epsilon: 0.06
# Episode: 914, Total Steps: 163344, Ep Step: 154, Raw Reward: 15.97, Epsilon: 0.06
# Episode: 915, Total Steps: 163477, Ep Step: 133, Raw Reward: 11.69, Epsilon: 0.06
# Episode: 916, Total Steps: 163638, Ep Step: 161, Raw Reward: -1.43, Epsilon: 0.06
# Episode: 917, Total Steps: 163787, Ep Step: 149, Raw Reward: 12.15, Epsilon: 0.06
# Episode: 918, Total Steps: 163987, Ep Step: 200, Raw Reward: -113.02, Epsilon: 0.06
# Episode: 919, Total Steps: 164134, Ep Step: 147, Raw Reward: 5.52, Epsilon: 0.06
# Episode: 920, Total Steps: 164288, Ep Step: 154, Raw Reward: 12.84, Epsilon: 0.06
# Episode: 921, Total Steps: 164488, Ep Step: 200, Raw Reward: -116.24, Epsilon: 0.06
# Episode: 922, Total Steps: 164638, Ep Step: 150, Raw Reward: 17.95, Epsilon: 0.06
# Episode: 923, Total Steps: 164771, Ep Step: 133, Raw Reward: 15.84, Epsilon: 0.06
# Episode: 924, Total Steps: 164971, Ep Step: 200, Raw Reward: -97.48, Epsilon: 0.06
# Episode: 925, Total Steps: 165127, Ep Step: 156, Raw Reward: -1.71, Epsilon: 0.06
# Episode: 926, Total Steps: 165284, Ep Step: 157, Raw Reward: 2.96, Epsilon: 0.06
# Episode: 927, Total Steps: 165421, Ep Step: 137, Raw Reward: 22.95, Epsilon: 0.06
# Episode: 928, Total Steps: 165582, Ep Step: 161, Raw Reward: 12.98, Epsilon: 0.06
# Episode: 929, Total Steps: 165731, Ep Step: 149, Raw Reward: 17.94, Epsilon: 0.06
# Episode: 930, Total Steps: 165879, Ep Step: 148, Raw Reward: 14.89, Epsilon: 0.06
# Episode: 931, Total Steps: 166029, Ep Step: 150, Raw Reward: 7.79, Epsilon: 0.06
# Episode: 932, Total Steps: 166166, Ep Step: 137, Raw Reward: 10.83, Epsilon: 0.06
# Episode: 933, Total Steps: 166308, Ep Step: 142, Raw Reward: 22.81, Epsilon: 0.06
# Episode: 934, Total Steps: 166457, Ep Step: 149, Raw Reward: 19.47, Epsilon: 0.06
# Episode: 935, Total Steps: 166601, Ep Step: 144, Raw Reward: 20.23, Epsilon: 0.06
# Episode: 936, Total Steps: 166752, Ep Step: 151, Raw Reward: 17.85, Epsilon: 0.06
# Episode: 937, Total Steps: 166893, Ep Step: 141, Raw Reward: 20.70, Epsilon: 0.06
# Episode: 938, Total Steps: 167028, Ep Step: 135, Raw Reward: 26.24, Epsilon: 0.06
# Episode: 939, Total Steps: 167166, Ep Step: 138, Raw Reward: 22.14, Epsilon: 0.06
# Episode: 940, Total Steps: 167309, Ep Step: 143, Raw Reward: 11.93, Epsilon: 0.06
# Episode: 941, Total Steps: 167446, Ep Step: 137, Raw Reward: 23.19, Epsilon: 0.06
# Episode: 942, Total Steps: 167591, Ep Step: 145, Raw Reward: 18.90, Epsilon: 0.06
# Episode: 943, Total Steps: 167746, Ep Step: 155, Raw Reward: 22.26, Epsilon: 0.06
# Episode: 944, Total Steps: 167879, Ep Step: 133, Raw Reward: 25.17, Epsilon: 0.06
# Episode: 945, Total Steps: 168014, Ep Step: 135, Raw Reward: 23.88, Epsilon: 0.06
# Episode: 946, Total Steps: 168164, Ep Step: 150, Raw Reward: 20.46, Epsilon: 0.06
# Episode: 947, Total Steps: 168309, Ep Step: 145, Raw Reward: 5.69, Epsilon: 0.06
# Episode: 948, Total Steps: 168449, Ep Step: 140, Raw Reward: 21.55, Epsilon: 0.06
# Episode: 949, Total Steps: 168594, Ep Step: 145, Raw Reward: 19.21, Epsilon: 0.06
# Episode: 950, Total Steps: 168738, Ep Step: 144, Raw Reward: 8.16, Epsilon: 0.06
# Episode: 951, Total Steps: 168870, Ep Step: 132, Raw Reward: 27.07, Epsilon: 0.06
# Episode: 952, Total Steps: 169014, Ep Step: 144, Raw Reward: 13.01, Epsilon: 0.06
# Episode: 953, Total Steps: 169170, Ep Step: 156, Raw Reward: 13.23, Epsilon: 0.06
# Episode: 954, Total Steps: 169315, Ep Step: 145, Raw Reward: 32.50, Epsilon: 0.06
# Episode: 955, Total Steps: 169460, Ep Step: 145, Raw Reward: 18.66, Epsilon: 0.06
# Episode: 956, Total Steps: 169606, Ep Step: 146, Raw Reward: 20.02, Epsilon: 0.06
# Episode: 957, Total Steps: 169783, Ep Step: 177, Raw Reward: 90.27, Epsilon: 0.06
# Episode: 958, Total Steps: 169935, Ep Step: 152, Raw Reward: 12.74, Epsilon: 0.06
# Episode: 959, Total Steps: 170105, Ep Step: 170, Raw Reward: 43.73, Epsilon: 0.06
# Episode: 960, Total Steps: 170259, Ep Step: 154, Raw Reward: 12.98, Epsilon: 0.06
# Episode: 961, Total Steps: 170442, Ep Step: 183, Raw Reward: -3.22, Epsilon: 0.06
# Episode: 962, Total Steps: 170598, Ep Step: 156, Raw Reward: 5.92, Epsilon: 0.06
# Episode: 963, Total Steps: 170752, Ep Step: 154, Raw Reward: 16.14, Epsilon: 0.06
# Episode: 964, Total Steps: 170908, Ep Step: 156, Raw Reward: 12.49, Epsilon: 0.06
# Episode: 965, Total Steps: 171067, Ep Step: 159, Raw Reward: -4.76, Epsilon: 0.06
# Episode: 966, Total Steps: 171209, Ep Step: 142, Raw Reward: 19.77, Epsilon: 0.05
# Episode: 967, Total Steps: 171359, Ep Step: 150, Raw Reward: 15.95, Epsilon: 0.05
# Episode: 968, Total Steps: 171513, Ep Step: 154, Raw Reward: 29.79, Epsilon: 0.05
# Episode: 969, Total Steps: 171665, Ep Step: 152, Raw Reward: 14.77, Epsilon: 0.05
# Episode: 970, Total Steps: 171817, Ep Step: 152, Raw Reward: 30.53, Epsilon: 0.05
# Episode: 971, Total Steps: 171967, Ep Step: 150, Raw Reward: 6.64, Epsilon: 0.05
# Episode: 972, Total Steps: 172117, Ep Step: 150, Raw Reward: 26.76, Epsilon: 0.05
# Episode: 973, Total Steps: 172268, Ep Step: 151, Raw Reward: 23.29, Epsilon: 0.05
# Episode: 974, Total Steps: 172399, Ep Step: 131, Raw Reward: 15.38, Epsilon: 0.05
# Episode: 975, Total Steps: 172539, Ep Step: 140, Raw Reward: 20.41, Epsilon: 0.05
# Episode: 976, Total Steps: 172691, Ep Step: 152, Raw Reward: 16.55, Epsilon: 0.05
# Episode: 977, Total Steps: 172837, Ep Step: 146, Raw Reward: 12.05, Epsilon: 0.05
# Episode: 978, Total Steps: 172985, Ep Step: 148, Raw Reward: 16.28, Epsilon: 0.05
# Episode: 979, Total Steps: 173124, Ep Step: 139, Raw Reward: 21.71, Epsilon: 0.05
# Episode: 980, Total Steps: 173275, Ep Step: 151, Raw Reward: 31.67, Epsilon: 0.05
# Episode: 981, Total Steps: 173437, Ep Step: 162, Raw Reward: -3.09, Epsilon: 0.05
# Episode: 982, Total Steps: 173578, Ep Step: 141, Raw Reward: 13.80, Epsilon: 0.05
# Episode: 983, Total Steps: 173730, Ep Step: 152, Raw Reward: 13.86, Epsilon: 0.05
# Episode: 984, Total Steps: 173874, Ep Step: 144, Raw Reward: 24.91, Epsilon: 0.05
# Episode: 985, Total Steps: 174022, Ep Step: 148, Raw Reward: 17.38, Epsilon: 0.05
# Episode: 986, Total Steps: 174154, Ep Step: 132, Raw Reward: 24.85, Epsilon: 0.05
# Episode: 987, Total Steps: 174284, Ep Step: 130, Raw Reward: 25.35, Epsilon: 0.05
# Episode: 988, Total Steps: 174432, Ep Step: 148, Raw Reward: 21.92, Epsilon: 0.05
# Episode: 989, Total Steps: 174570, Ep Step: 138, Raw Reward: 24.06, Epsilon: 0.05
# Episode: 990, Total Steps: 174717, Ep Step: 147, Raw Reward: 16.85, Epsilon: 0.05
# Episode: 991, Total Steps: 174855, Ep Step: 138, Raw Reward: 21.68, Epsilon: 0.05
# Episode: 992, Total Steps: 175000, Ep Step: 145, Raw Reward: 18.57, Epsilon: 0.05
# Episode: 993, Total Steps: 175143, Ep Step: 143, Raw Reward: 18.19, Epsilon: 0.05
# Episode: 994, Total Steps: 175301, Ep Step: 158, Raw Reward: 41.00, Epsilon: 0.05
# Episode: 995, Total Steps: 175461, Ep Step: 160, Raw Reward: 38.49, Epsilon: 0.05
# Episode: 996, Total Steps: 175635, Ep Step: 174, Raw Reward: 2.40, Epsilon: 0.05
# Episode: 997, Total Steps: 175789, Ep Step: 154, Raw Reward: 17.00, Epsilon: 0.05
# Episode: 998, Total Steps: 175947, Ep Step: 158, Raw Reward: 39.13, Epsilon: 0.05
# Episode: 999, Total Steps: 176096, Ep Step: 149, Raw Reward: 15.04, Epsilon: 0.05
#
# ~~~~~~Interval Save: Model saved.
#
# Episode: 1000, Total Steps: 176247, Ep Step: 151, Raw Reward: 33.13, Epsilon: 0.05

# %%
# Recreate the agent and environment as during training
DRL = Model_TrainTest(RL_hyperparams)
DRL.agent.main_network.load_state_dict(torch.load('./final_weights_1000.pth'))
DRL.agent.main_network.eval()
# Out:
# DQN_Network(
#   (FC): Sequential(
#     (0): Linear(in_features=2, out_features=12, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=12, out_features=8, bias=True)
#     (3): ReLU(inplace=True)
#     (4): Linear(in_features=8, out_features=3, bias=True)
#   )
# )

# %%
# Make sure to use the same environment settings as during training
env = gym.make(ENV_NAME, render_mode="human")
state, _ = env.reset(seed=seed)
done = False
truncation = False

# Set agent to evaluation mode
DRL.agent.main_network.eval()

while not done and not truncation:
    # Convert state to tensor if needed
    if not torch.is_tensor(state):
        state_tensor = torch.as_tensor(state, dtype=torch.float32, device=device)
    else:
        state_tensor = state
    with torch.no_grad():
        q_values = DRL.agent.main_network(state_tensor)
        action = torch.argmax(q_values).item()
    next_state, reward, done, truncation, _ = env.step(action)
    state = next_state

env.close()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
